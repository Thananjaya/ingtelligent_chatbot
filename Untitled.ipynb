# %%
import numpy as np
import tensorflow as tf
import re
import time

# %%
lines = open("movie_lines.txt", encoding="utf-8", errors="ignore").read().split("\n")
conversations = open("movie_conversations.txt", encoding="utf-8", errors="ignore").read().split("\n")

# %%
lines_dict = {}
for line in lines:
    _line = line.split(" +++$+++ ")
    if len(_line) == 5:
        lines_dict[_line[0]] = _line[4]

# %%
conversations_ids = []
for conversation in conversations[:-1]:
    _conversation = conversation.split(" +++$+++ ")[-1][1:-1].replace("'", "").replace(" ", "")
    conversations_ids.append(_conversation.split(","))

# %%
questions = []
answers = []
for conversation in conversations_ids:
    for i in range(len(conversation) - 1):
        questions.append(lines_dict[conversation[i]])
        answers.append(lines_dict[conversation[i+1]])

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"workin'", "working", text)
    text = re.sub(r"goin'", "going", text)
    text = re.sub(r"[-()\"#/@;:<>{}+=~|.,?!]", "", text)
    return text

# %%
cleaned_questions= []
cleaned_answers = []
for question in questions:
    cleaned_questions.append(clean_text(question))

for answer in answers:
    cleaned_answers.append(clean_text(answer))

# %%
# checking for frequency of words
word_count = {}
for question in cleaned_questions:
    for word in question.split():
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

for answer in cleaned_answers:
    for word in answer.split():
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

# %%
word_count
# Out:
# {'crapped': 4,
#  'gifford': 4,
#  'monkeyboy': 1,
#  'target': 126,
#  'regent': 9,
#  'five': 1768,
#  "gottschalk's": 2,
#  'ectomorphicon': 1,
#  'chiatrist': 2,
#  'playboys': 1,
#  'debo': 4,
#  'wellpaid': 3,
#  'trumpets': 6,
#  'nowhereand': 1,
#  "denham's": 1,
#  'safeway': 2,
#  'fares': 8,
#  'revolutionists': 1,
#  'flagwaving': 2,
#  'bidness': 5,
#  "hole's": 1,
#  'rrgh': 1,
#  'deejayed': 2,
#  'goodday': 3,
#  'vasquez': 6,
#  'if': 18955,
#  'nudist': 3,
#  "beer's": 4,
#  'supply': 84,
#  'seismographs': 5,
#  'janitor': 22,
#  'nicest': 15,
#  'alot': 18,
#  "'easy": 1,
#  'salute': 21,
#  'cape': 36,
#  'roots': 29,
#  'dei': 4,
#  'startle': 7,
#  "ruben's": 3,
#  'michelin': 4,
#  'liable': 40,
#  'marharagi': 1,
#  'automatic': 42,
#  'selfexploration': 1,
#  'driveby': 2,
#  'driveway': 10,
#  'kruczynski': 5,
#  'uworldu': 6,
#  'notoriety': 3,
#  'precognition': 1,
#  'scumsicle': 1,
#  'octane': 2,
#  'sayingwhat': 1,
#  'sheepskin': 1,
#  'countryside': 8,
#  'glossy': 6,
#  "superhero's": 8,
#  "wouldamone's": 2,
#  'shelters': 12,
#  'whooping': 11,
#  'steel': 78,
#  'infect': 8,
#  'napping': 2,
#  'brett': 16,
#  'props': 13,
#  "juno's": 2,
#  'blissfully': 2,
#  "can'": 7,
#  "scurvy's": 2,
#  'notification': 3,
#  'tennis': 55,
#  'punchline': 8,
#  'wallhanging': 2,
#  'mindboggling': 1,
#  "gastro's": 1,
#  'feel': 3231,
#  'correspondents': 2,
#  'supporter': 8,
#  'alvin': 4,
#  'pale': 51,
#  'cc': 10,
#  'heraldi': 1,
#  'uncomfortable': 68,
#  "'old": 2,
#  "required'": 2,
#  'roadhouse': 5,
#  'jjefferson': 1,
#  'terrell': 2,
#  'centro': 1,
#  'hissy': 1,
#  'dinneri': 2,
#  'burundi': 1,
#  'ninetyninth': 2,
#  'unders': 1,
#  'falsely': 14,
#  'hoocha': 2,
#  'burritos': 1,
#  'valley': 119,
#  'thatsir': 1,
#  'folds': 8,
#  'know': 31884,
#  'grams': 7,
#  "greenly's": 1,
#  'subscription': 16,
#  'demise': 14,
#  'episohistorical': 1,
#  'nearby': 24,
#  'pendant': 6,
#  'suffused': 2,
#  'getoutof': 2,
#  'disappointments': 2,
#  "brolly's": 1,
#  'greenhouses': 1,
#  'twentyfirst': 4,
#  "lion's": 4,
#  'iinevitable': 2,
#  'anacott': 6,
#  'scairt': 5,
#  'doon': 2,
#  'site': 58,
#  'bonney': 1,
#  'udoneu': 15,
#  'hallway': 25,
#  'hitchhiked': 2,
#  'softie': 5,
#  'adopt': 23,
#  'hilarious': 20,
#  'sector': 73,
#  'cabaret': 1,
#  'detective': 322,
#  'rumbles': 2,
#  'chinos': 2,
#  'scenario': 24,
#  'ohmy': 2,
#  'adrenals': 1,
#  'neurosystems': 2,
#  'sulk': 3,
#  'grenadine': 1,
#  'namesake': 2,
#  'keyboard': 11,
#  'ante': 7,
#  'nyborg': 4,
#  'straightforward': 8,
#  'birthplace': 2,
#  'professions': 3,
#  'sheraton': 10,
#  'marliston': 4,
#  'eddy': 34,
#  'twinkeys': 1,
#  'younger': 120,
#  "'small'": 1,
#  'stolen': 143,
#  'normally': 66,
#  "uhdidn't": 2,
#  'overrate': 2,
#  'mothering': 2,
#  'wear': 491,
#  'baltimore': 62,
#  'jolla': 2,
#  'nuketell': 1,
#  'pornography': 19,
#  'tenuous': 2,
#  'noble': 79,
#  'reads': 48,
#  'semiformal': 1,
#  "jivin'": 4,
#  "sensenet's": 2,
#  'menow': 2,
#  'jackal': 2,
#  'outdoortype': 2,
#  'vanishes': 2,
#  'variety': 23,
#  'brotheryou': 1,
#  'wetlands': 1,
#  'himball': 1,
#  'uwaru': 4,
#  '*question*': 2,
#  'hah': 50,
#  "y'get": 2,
#  'civ': 1,
#  'hargrove': 1,
#  'funkadelic': 3,
#  'date': 555,
#  'psycholingusitics': 2,
#  'stomach': 157,
#  'html': 1,
#  'banking': 24,
#  'applicants': 5,
#  'save': 710,
#  'mores': 4,
#  "'wearing'": 1,
#  'book': 883,
#  'terrakian': 1,
#  "'hello'": 3,
#  'togs': 1,
#  "five's": 4,
#  "ballin'": 2,
#  'coils': 3,
#  'flayed': 5,
#  'vaporous': 2,
#  "milholland's": 1,
#  'illness': 45,
#  'slingshot': 5,
#  'heard': 2150,
#  'outfox': 1,
#  'sorriest': 1,
#  'untainted': 1,
#  'zordon': 3,
#  'calabrian': 3,
#  'sicking': 2,
#  'lsd': 10,
#  'sciencei': 1,
#  'daytoday': 5,
#  'beauties': 12,
#  'rememberyou': 3,
#  'emptynest': 1,
#  'esdras': 4,
#  'mortenson': 2,
#  'ufascinatingu': 1,
#  'choppers': 10,
#  'roper': 18,
#  'monterreys': 1,
#  'electing': 1,
#  'malta': 1,
#  'nothin': 15,
#  'brom': 6,
#  'baptism': 9,
#  'reassess': 1,
#  'theninject': 1,
#  'hydrated': 1,
#  'groundwater': 2,
#  'twotwofifty': 1,
#  'lorings': 1,
#  'acting': 311,
#  'recuperating': 3,
#  'troopres': 1,
#  'handsaw': 2,
#  'pimp': 52,
#  'leaves': 186,
#  'popeof': 1,
#  "'94": 4,
#  'waive': 1,
#  'smurf': 2,
#  'fernandez': 5,
#  'forearm': 3,
#  'niles': 3,
#  'reputationlike': 1,
#  "credit's": 2,
#  'bitch': 569,
#  'babaloo': 1,
#  'halcyon': 4,
#  'momentum': 4,
#  'lykas': 2,
#  '_knowledge_': 2,
#  'fairly': 49,
#  'aahby': 2,
#  'inlaws': 3,
#  'coursecome': 1,
#  'dullsville': 1,
#  'rootswe': 2,
#  'youwhy': 1,
#  'golly': 24,
#  "firstso's": 1,
#  "*worl'*": 1,
#  "throat's": 1,
#  "allisn't": 1,
#  "f'it": 2,
#  'wooshed': 1,
#  '12year': 2,
#  'drunkards': 4,
#  'oldtime': 1,
#  'farts': 11,
#  'washandwear': 2,
#  'familiarize': 4,
#  'potato': 33,
#  'wellllll': 2,
#  'practising': 3,
#  'whiteboy': 1,
#  'lonnie': 13,
#  'spiro': 6,
#  'rolledback': 2,
#  'dispatches': 11,
#  'interact': 8,
#  '*own*': 3,
#  'catharsis': 2,
#  'uallu': 23,
#  'burgler': 1,
#  'kleenex': 5,
#  'shemp': 14,
#  'byebye': 20,
#  'git': 70,
#  'fears': 31,
#  'cappedoff': 1,
#  'prarie': 2,
#  'charisma': 6,
#  'responsibilitymy': 1,
#  'yesi': 14,
#  "allwoman's": 1,
#  'okayattractiveugly': 1,
#  'parrot': 15,
#  'neededjust': 1,
#  'stallworth': 1,
#  "freeze's": 3,
#  'veer': 1,
#  'alconia': 2,
#  'woolridge': 3,
#  'cofounders': 2,
#  'blunder': 2,
#  'wonder': 542,
#  'matter': 1876,
#  'bitchbox': 1,
#  'bulkheads': 2,
#  'bookdownthetrousers': 2,
#  'shaggy': 2,
#  'superstar': 8,
#  'chester': 3,
#  'ucreditu': 6,
#  'travelwhenever': 2,
#  'improvedhow': 1,
#  'deluxe': 9,
#  'adam': 138,
#  "taupin's": 2,
#  'tailing': 4,
#  'coxswain': 4,
#  'overtenderizing': 1,
#  'insincerity': 1,
#  'nostalgic': 3,
#  'tread': 12,
#  'oncuont': 1,
#  'overheating': 1,
#  'heheh': 1,
#  'soared': 2,
#  'alcoholic': 29,
#  'essional': 1,
#  "buy'm": 1,
#  "larry's": 11,
#  'angola': 8,
#  'lighting': 16,
#  'driedup': 2,
#  'humorous': 9,
#  'jackrabbit': 4,
#  'format': 4,
#  'hamhanded': 2,
#  'givem': 1,
#  'calvinist': 2,
#  'tennyson': 1,
#  'problem_': 1,
#  '*anybody*': 4,
#  'me]': 11,
#  'quiche': 8,
#  'bono': 10,
#  "hare's": 1,
#  "stealin'": 2,
#  'intervening': 3,
#  'mucoid': 1,
#  'dong': 12,
#  "caprio's": 1,
#  'shutup': 28,
#  'pinky': 8,
#  'burlington': 1,
#  'vocational': 1,
#  'bristles': 1,
#  'hotfooting': 2,
#  'alfredo': 15,
#  'involve': 28,
#  'mcluhan': 7,
#  'deceive': 19,
#  'rauss': 3,
#  'childless': 1,
#  'spooky': 31,
#  'sail': 74,
#  'plaits': 2,
#  'legalized': 1,
#  'springbok': 2,
#  'gelding': 2,
#  "montaldo's": 2,
#  'dance[12]': 1,
#  'cnote': 2,
#  'sansom': 1,
#  'upassu': 2,
#  'scrutiny': 3,
#  'infectee': 2,
#  'sneezed': 2,
#  'sympathy': 30,
#  'aloha': 8,
#  'nicolette': 3,
#  'undesirable': 4,
#  'melanie': 55,
#  'farr': 2,
#  'dads': 7,
#  'morale': 9,
#  "bremer's": 2,
#  'youngsters': 11,
#  'spilt': 3,
#  "'people'": 3,
#  'selena': 19,
#  'ostinato': 1,
#  'enchant': 3,
#  'heroinei': 2,
#  'conflicting': 2,
#  'fortunately': 30,
#  'popsweet': 1,
#  'indeedy': 4,
#  'serene': 5,
#  'testimonythat': 1,
#  'mediums': 2,
#  'sayest': 2,
#  'hegot': 2,
#  'box': 334,
#  'plotting': 15,
#  'earl': 145,
#  'hinton': 1,
#  'singleness': 1,
#  'sabotage': 37,
#  'marseilles': 15,
#  '*some*': 1,
#  'addressed': 23,
#  "registration's": 2,
#  'intentional': 9,
#  'glands': 15,
#  'soggy': 7,
#  'blacken': 4,
#  'ruler': 16,
#  'rideaway': 2,
#  'uuh': 3,
#  'arethis': 1,
#  'oran': 2,
#  'fortieth': 3,
#  'cretan': 1,
#  'auteur': 1,
#  'golook': 2,
#  'ubeautifulu': 5,
#  'steno': 1,
#  'junkies': 15,
#  'antitoxin': 5,
#  "dog's": 31,
#  "twister's": 1,
#  'masturbating': 3,
#  'inoperable': 2,
#  'windscreen': 2,
#  'stronghold': 5,
#  "robinson's": 2,
#  'welly': 6,
#  'modalities': 1,
#  'biochemistry': 1,
#  'merde': 7,
#  'contracting': 3,
#  'turkienistan': 3,
#  'koontz': 5,
#  'uuuuugh': 1,
#  'traveling': 59,
#  'weenie': 3,
#  'coors': 6,
#  'jamesyounger': 5,
#  "wollsten's": 1,
#  'fireball': 4,
#  'tripledogdare': 1,
#  'stables': 2,
#  'beforehand': 13,
#  'prettiest': 16,
#  'uhoutel': 4,
#  'membrane': 5,
#  'cledus': 8,
#  "bumpin'": 1,
#  "romari's": 1,
#  'guessed': 55,
#  'jockey': 26,
#  'laddie': 16,
#  'lunged': 1,
#  'gaigern': 9,
#  'welllooks': 3,
#  'change': 1129,
#  'connectors': 4,
#  'jurgen': 1,
#  'montage': 3,
#  '1814': 1,
#  'reunions': 5,
#  'fluties': 4,
#  "worth's": 7,
#  'hence': 43,
#  'allsinging': 2,
#  "'admire'": 1,
#  'barbie': 14,
#  'orpheus': 2,
#  'excops': 3,
#  'mobilization': 5,
#  'sug': 2,
#  'others': 558,
#  "beth's": 4,
#  'upperclass': 1,
#  'usendu': 2,
#  "democrats'": 1,
#  "'shit": 2,
#  'smear': 28,
#  '25s': 2,
#  'architectbut': 2,
#  'mornay': 1,
#  'lockyer': 2,
#  'exam': 22,
#  'pword': 2,
#  'medcart': 1,
#  'dowry': 2,
#  'mohra': 6,
#  "sleepthere's": 1,
#  'crawlspace': 4,
#  'suspiciously': 2,
#  'rina': 6,
#  'uncleor': 1,
#  'twinkling': 2,
#  'drinkers': 3,
#  'blain': 2,
#  'ninetoed': 1,
#  'lechem': 2,
#  'sapped': 1,
#  'planing': 2,
#  'prideswallowing': 1,
#  'syphilis': 1,
#  'stopstop': 1,
#  'nastiness': 8,
#  'precedes': 2,
#  'wiseass': 5,
#  'heaved': 2,
#  'amused': 17,
#  'lewis': 51,
#  'siracuse': 2,
#  'infects': 5,
#  'esperitu': 2,
#  'uanywayu': 2,
#  'greatest': 238,
#  'peopleit': 2,
#  'thisahere': 2,
#  'extracts': 2,
#  'quel': 2,
#  'anythingespecially': 1,
#  'dialect': 3,
#  "shot's": 5,
#  'yitzchak': 2,
#  'principals': 7,
#  'gangway': 1,
#  "lootin'": 2,
#  'westinghouse': 4,
#  'rolltop': 10,
#  'mussburger': 5,
#  'saunter': 1,
#  'datsun': 3,
#  "dinosaur's": 6,
#  'forgetfulness': 2,
#  'kraut': 11,
#  "upsettin'": 3,
#  'manicured': 1,
#  'leadeth': 1,
#  'padlock': 6,
#  'longe': 3,
#  'indecent': 2,
#  'hint': 58,
#  "buyin'": 13,
#  'elena': 37,
#  '289': 1,
#  'liner': 14,
#  'gallons': 13,
#  'yesyou': 3,
#  'hardtop': 2,
#  "woofin'": 1,
#  'easily': 118,
#  'awakeu': 1,
#  'footwork': 1,
#  'excavating': 1,
#  'heyhey': 4,
#  'intervals': 10,
#  'sowanta': 1,
#  'lollygaggers': 1,
#  'concerns': 57,
#  'inresidence': 1,
#  "cavalier'": 2,
#  'stipulation': 3,
#  'defiance': 5,
#  'sands': 3,
#  'polo': 27,
#  'copness': 1,
#  'filmic': 2,
#  'guardians': 5,
#  'yoyo': 14,
#  'bile': 2,
#  'jeesuz': 2,
#  'ubeachu': 1,
#  'compromisesu': 1,
#  'lobes': 4,
#  'moreover': 24,
#  'rosella': 1,
#  'lawnmowers': 1,
#  'pingala': 8,
#  'borderwhat': 2,
#  'welfare': 38,
#  'pigeons': 34,
#  'myeye': 2,
#  'sizzled': 1,
#  'deviate': 6,
#  'kantrowitz': 2,
#  'recovered': 37,
#  'gun': 1008,
#  'piers': 8,
#  'pursuant': 1,
#  'brewing': 5,
#  'war': 1003,
#  'doozy': 4,
#  'populations': 1,
#  'sensuality': 2,
#  'chatting': 14,
#  'dela': 24,
#  'rahtid': 1,
#  'stage': 119,
#  '1292': 2,
#  'ateam': 1,
#  'manbiters': 2,
#  'iene': 1,
#  'saps': 9,
#  "senate's": 1,
#  'hellandahalf': 3,
#  'thank': 2634,
#  'faye': 5,
#  "'cyclops'": 1,
#  'maitland': 2,
#  'dreading': 3,
#  'amys': 1,
#  'videotaping': 1,
#  "'seventy": 2,
#  'raton': 1,
#  'phobia': 4,
#  'slime': 20,
#  'moron': 76,
#  'screenit': 1,
#  'antiintellectual': 1,
#  'runned': 2,
#  'soliciting': 6,
#  "election's": 1,
#  'milady': 1,
#  'della': 11,
#  '$4': 1,
#  'gears': 11,
#  'chickened': 14,
#  'considers': 11,
#  'bachelor': 68,
#  'conor': 24,
#  'ordained': 6,
#  'corral': 6,
#  'contempt': 23,
#  'enigma': 7,
#  'canadians': 7,
#  "pussy's": 2,
#  'uany': 1,
#  'swallow]': 1,
#  'areilly': 5,
#  'gander': 7,
#  'rationalizations': 1,
#  'inland': 9,
#  'glasses': 138,
#  'probed': 1,
#  'jigsaw': 4,
#  '97': 10,
#  'coditioning': 1,
#  '1856': 2,
#  'sterling': 9,
#  'ted': 273,
#  'unimpeachable': 1,
#  'withdraws': 4,
#  'genitalia': 2,
#  'predominant': 1,
#  'stranger': 91,
#  'uhenchmenu': 2,
#  "'moffit'": 2,
#  'beachwood': 2,
#  "while'": 3,
#  'repro': 2,
#  'stairwayi': 2,
#  'redblooded': 4,
#  'youam': 1,
#  'spysat': 2,
#  'assaults': 4,
#  'kickass': 5,
#  '24hour': 6,
#  'nowjust': 3,
#  'needed': 418,
#  'honeymooning': 1,
#  "doesn'tsee": 2,
#  'assignment': 86,
#  'exorbitant': 1,
#  'cornering': 1,
#  'nineveh': 2,
#  'investigators': 16,
#  'graver': 2,
#  'uguessu': 2,
#  'handleright': 2,
#  "guy'": 1,
#  'renaissance': 12,
#  'cremate': 2,
#  "cheatin'": 2,
#  'taphonomy': 2,
#  'tracker': 5,
#  "prayin'": 8,
#  'chief': 415,
#  'isand': 1,
#  'treborn': 6,
#  'electionthe': 1,
#  'zachary': 1,
#  'knowthis': 1,
#  'qood': 1,
#  'evidentwith': 2,
#  'ravish': 1,
#  'antagonist': 1,
#  'butyou': 12,
#  'sorryfor': 1,
#  'pencilnecked': 1,
#  "cluett's": 8,
#  'cylone': 1,
#  'kirshner': 5,
#  'magnum': 17,
#  'officerseveral': 2,
#  'ubornu': 2,
#  'mandatory': 10,
#  'clewlines': 1,
#  'roadie': 3,
#  'airshaft': 1,
#  "maggie's": 4,
#  'androids': 4,
#  'zapper': 3,
#  'egad': 2,
#  'arches': 1,
#  "room's": 12,
#  'gangland': 2,
#  'woo': 6,
#  'fastokay': 1,
#  'backif': 1,
#  "it'shim": 2,
#  'bodell': 7,
#  'amaze': 9,
#  'dyson': 9,
#  'goodall': 1,
#  'pauper': 1,
#  'anythingmust': 1,
#  "atryin'": 2,
#  'jumpsuit': 1,
#  'sshh': 6,
#  "correct'": 2,
#  'smokescreen': 1,
#  'chain': 88,
#  'intentionally': 12,
#  'america]': 2,
#  'deaaaddddd': 1,
#  'fennel': 1,
#  "lounds's": 2,
#  'debating': 5,
#  'secretarygeneral': 1,
#  'trieckonal': 2,
#  'yugoslavia': 12,
#  'redundancies': 1,
#  'fingerpainting': 1,
#  'deeper': 57,
#  'symbolic': 10,
#  "'bus": 1,
#  'nonetheless': 10,
#  'gushing': 3,
#  'outfits': 14,
#  'spicoli': 10,
#  '948': 1,
#  'bipartisan': 2,
#  'barcelona': 5,
#  'of': 56307,
#  'rufferwell': 1,
#  'addictis': 6,
#  'raisin': 5,
#  'volsung': 2,
#  'shavings': 3,
#  'kar': 1,
#  'avaycha': 2,
#  '100000': 1,
#  'carats': 3,
#  'stamped': 16,
#  'spit': 78,
#  'endure': 19,
#  'dutton': 6,
#  'afloat': 4,
#  'sela': 4,
#  'suffered': 53,
#  'sierras': 1,
#  'altercation': 3,
#  'areooh': 1,
#  'drawer': 41,
#  'minutewhat': 2,
#  'itis': 2,
#  '*captain*': 2,
#  "superman's": 13,
#  'harness': 7,
#  'saddle': 19,
#  'niggertown': 1,
#  "venom's": 2,
#  "nadia's": 1,
#  'destines': 2,
#  'whwhy': 2,
#  'toothbrush': 19,
#  'disastrously': 2,
#  'kidnaps': 4,
#  'dj': 15,
#  'whattalk': 1,
#  'theoryu': 1,
#  "father's": 313,
#  'mayo': 49,
#  'ags18': 1,
#  "barnhardt's": 2,
#  'uharveyu': 2,
#  'looklook': 2,
#  'arimathaea': 2,
#  'meanit': 2,
#  'advantage': 99,
#  'wastinghowever': 2,
#  'stuntdriving': 2,
#  'circuits': 18,
#  'unsual': 1,
#  'decibel': 1,
#  'oceans': 15,
#  'dick': 427,
#  'bajoran': 2,
#  'blaupunkt': 2,
#  'hiyes': 3,
#  'umilesu': 2,
#  'alllike': 2,
#  'iswasyour': 1,
#  'bollocksed': 1,
#  'circled': 5,
#  'cushman': 6,
#  'effectively': 6,
#  'cleanest': 2,
#  'foolishness': 7,
#  'needles': 26,
#  'clients': 78,
#  "'50's": 1,
#  'vien': 1,
#  "prague's": 1,
#  'suddenly': 249,
#  'fatty': 3,
#  'strengths': 7,
#  'consistency': 8,
#  'companionsis': 2,
#  'quarts': 1,
#  'emmett': 17,
#  'exacting': 7,
#  'plea': 12,
#  "issue's": 2,
#  'harvests': 1,
#  'circuitry': 3,
#  'macaw': 2,
#  'mythand': 1,
#  'sneaks': 2,
#  'protegee': 1,
#  'squares': 13,
#  'cars': 235,
#  "sleuthin'": 1,
#  'reinstated': 9,
#  'bart': 12,
#  'crowbar': 5,
#  'blueprints': 14,
#  '1895you': 2,
#  'babe': 162,
#  'kirku': 1,
#  'sandford': 1,
#  'uhappenu': 1,
#  'coco': 9,
#  "'please": 1,
#  'esprit': 2,
#  'dishonorably': 2,
#  'damnedifi': 1,
#  "teamster's": 1,
#  'gaiijin': 7,
#  'lomb': 1,
#  'hmmn': 3,
#  'iwithout': 2,
#  'trychticholorate': 6,
#  'supper': 82,
#  'upaintu': 2,
#  "h'mm": 1,
#  'yang': 1,
#  'stove': 18,
#  "joint's": 2,
#  'unpacking': 1,
#  'incomparable': 2,
#  'antenna': 13,
#  'meteorolog': 2,
#  'cokes': 14,
#  'dweeb': 4,
#  'pluchinsky': 2,
#  'infraction': 2,
#  'peaceloving': 5,
#  'iamericansi': 2,
#  "side's": 2,
#  "'intimate'": 1,
#  'thatummmaybe': 2,
#  'aristocratic': 2,
#  'industrialist': 1,
#  'billfoldi': 1,
#  'grub': 8,
#  'deltoid': 9,
#  'elbows': 20,
#  'unconnected': 5,
#  'uansweru': 3,
#  'danielson': 7,
#  'scot': 3,
#  'sensible': 29,
#  "sleep'": 1,
#  'temperance': 1,
#  't1000': 8,
#  'abombs': 2,
#  'volunteering': 4,
#  'trances': 1,
#  'hist': 1,
#  'thing': 5822,
#  'rewrites': 2,
#  'ahmar': 1,
#  'suggestions': 26,
#  'cabinat': 2,
#  'ubreakfastu': 2,
#  'uifu': 8,
#  'first': 3933,
#  'crushes': 8,
#  'beckett': 39,
#  'diver': 11,
#  'tasteand': 1,
#  'spurts': 7,
#  'thinkingcap': 1,
#  'kirsty': 29,
#  'unfitboythat': 1,
#  'freeroaming': 2,
#  "or's": 4,
#  'digiorgio': 2,
#  'kicks': 51,
#  "custom's": 1,
#  'chongo': 1,
#  'mapped': 1,
#  'cussing': 2,
#  'appropriate': 74,
#  'batya': 1,
#  'fullbody': 3,
#  'dayshift': 2,
#  'daphne': 36,
#  'nailing': 8,
#  'hupmobile': 2,
#  'gall': 7,
#  'zeroed': 3,
#  'eggiwegs': 2,
#  '45000': 1,
#  'efficiency': 16,
#  'kintner': 1,
#  'freshman': 20,
#  'gozaranuka': 2,
#  'penis': 56,
#  'emergencies': 15,
#  'circus': 53,
#  "me'": 35,
#  'realizing': 15,
#  'j2l': 2,
#  'hamstring': 2,
#  'mmmmmmmmmm': 1,
#  'beaton': 2,
#  'vlad': 7,
#  'darrell': 30,
#  "dwight's": 2,
#  'flogging': 4,
#  'familyowned': 1,
#  'clit': 2,
#  'bingham': 1,
#  'sores': 1,
#  'included': 29,
#  'killedbut': 1,
#  "decide'": 2,
#  'consider': 249,
#  "y'knowwhati": 7,
#  'appreciated': 21,
#  'unten': 1,
#  '4th': 21,
#  'paraikete': 1,
#  'branton': 1,
#  'naish': 1,
#  'madox': 4,
#  'eliminations': 1,
#  'forrests': 1,
#  'smarting': 2,
#  "sammy's": 4,
#  'deckard': 10,
#  'tothe': 2,
#  'ui': 74,
#  'fragged': 5,
#  'reviewer': 1,
#  'katharine': 24,
#  'seein': 1,
#  'shocking': 27,
#  'razorbut': 2,
#  "criss's": 2,
#  'finei': 1,
#  'acknowledgements': 1,
#  "geoffrey's": 1,
#  "scuff's": 1,
#  ...}

# %%
#tokenization
threshold = 25
question_tokens = {}
word_number = 0
for word, count in word_count.items():
    if count >= threshold:
        question_tokens[word] = word_number
        word_number += 1
        
word_number = 0
answer_tokens = {}
for word, count in word_count.items():
    if count >= threshold:
        answer_tokens[word] = word_number
        word_number += 1

# %%
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']
for token in tokens:
    question_tokens[token] = len(question_tokens) + 1
    answer_tokens[token] = len(answer_tokens) + 1

# %%
answers_inverse = {w_i: w for w, w_i in answer_tokens.items()}

# %%
# adding <EOS> in cleaned_answers

for i in range(len(cleaned_answers)):
    cleaned_answers[i] += ' <EOS>'

# %%
questions_to_int = []
for question in cleaned_questions:
    ints = []
    for word in question.split():
        if word not in question_tokens:
            ints.append(question_tokens['<OUT>'])
        else:
            ints.append(question_tokens[word])
    questions_to_int.append(ints)
answers_to_int = []
for answer in cleaned_answers:
    ints = []
    for word in answer.split():
        if word not in answer_tokens:
            ints.append(answer_tokens['<OUT>'])
        else:
            ints.append(answer_tokens[word])
    answers_to_int.append(ints)

# %%
questions_to_int
# Out:
# [[3818,
#   6647,
#   5224,
#   7141,
#   5356,
#   7385,
#   7385,
#   4264,
#   5379,
#   7385,
#   6507,
#   4090,
#   1524,
#   634,
#   7385,
#   2788,
#   2457,
#   1721,
#   4153,
#   6442,
#   7385,
#   6974],
#  [6367,
#   5818,
#   6274,
#   6647,
#   3366,
#   4766,
#   2004,
#   7385,
#   2,
#   5981,
#   1718,
#   5078,
#   2004,
#   3008],
#  [6478, 6442, 7385, 4264, 7385, 4264, 7385, 4424, 5254],
#  [3008,
#   6507,
#   7152,
#   905,
#   3909,
#   5981,
#   1718,
#   7224,
#   7163,
#   5243,
#   1718,
#   932,
#   6980,
#   6974],
#  [6952, 6952, 987, 3422, 1697, 6647, 6119, 1869, 5557, 1284, 7385],
#  [3789],
#  [6442,
#   103,
#   1718,
#   3789,
#   5818,
#   7356,
#   2917,
#   6442,
#   2030,
#   88,
#   5557,
#   794,
#   7385,
#   6458,
#   88,
#   3925,
#   3422,
#   4220,
#   5818,
#   4043,
#   28,
#   5925,
#   6099,
#   5437],
#  [2025],
#  [7385,
#   7258,
#   6099,
#   1856,
#   2282,
#   1362,
#   3620,
#   5056,
#   5383,
#   6099,
#   2846,
#   2199,
#   7042,
#   2899,
#   3035,
#   545,
#   3565,
#   2366,
#   6099,
#   2564,
#   1503,
#   88,
#   3035,
#   2461,
#   6242],
#  [4828, 2, 4688, 6647, 3101, 3181, 3600, 5557, 5504],
#  [7385, 4251, 7385, 7141, 1718, 3422, 7179],
#  [6389, 3234, 3008, 6507, 537, 1685, 6442, 7385],
#  [5818,
#   5072,
#   6478,
#   297,
#   2282,
#   14,
#   5477,
#   2282,
#   134,
#   5981,
#   444,
#   5818,
#   297,
#   2282,
#   14,
#   1100,
#   870,
#   2366,
#   1742,
#   6442,
#   3706,
#   938,
#   6507,
#   5477,
#   894,
#   5437,
#   3714,
#   1316,
#   6266,
#   2366,
#   6849,
#   5818,
#   1869,
#   2236,
#   2663,
#   3422,
#   1267,
#   503,
#   2282,
#   630,
#   3909,
#   3422,
#   7179,
#   2282,
#   4456],
#  [5981, 1718, 651, 987, 2045, 5557, 4834, 3313],
#  [5477, 1718, 6223, 5216, 3181, 6442, 7385, 5557, 28, 6554, 7385],
#  [4525],
#  [3008, 2564, 6242, 4153, 932, 2435],
#  [3008, 1869, 3422, 5604, 2389, 5557, 4092],
#  [5477, 5072, 3008, 5162, 932, 2353, 2282, 3161, 2366, 5981],
#  [2235, 1869],
#  [5818,
#   3620,
#   3620,
#   3620,
#   1981,
#   1997,
#   1205,
#   5818,
#   4043,
#   6478,
#   644,
#   3422,
#   4220,
#   6625],
#  [6099, 1718, 6478, 5557],
#  [4031,
#   6952,
#   5818,
#   1081,
#   5557,
#   3480,
#   88,
#   7385,
#   7385,
#   2663,
#   3313,
#   88,
#   2593,
#   7385,
#   7224,
#   5818,
#   7356,
#   3012,
#   2235,
#   6099,
#   1718,
#   6478,
#   7385,
#   7385,
#   7385],
#  [7224, 5981, 1718, 6442, 6376, 88, 3848, 6099, 4397, 3012, 3527],
#  [2431],
#  [3008, 14, 7385],
#  [1869, 723, 6986],
#  [5818,
#   6564,
#   1685,
#   3008,
#   2084,
#   2917,
#   6442,
#   4749,
#   1205,
#   3008,
#   6219,
#   3677,
#   2282,
#   1362,
#   4269],
#  [5818, 545],
#  [6367, 6952],
#  [2899, 5981, 1718, 4577, 3008, 503, 2282, 134],
#  [1205],
#  [2899,
#   7385,
#   6991,
#   2,
#   3008,
#   1997,
#   7360,
#   2334,
#   3008,
#   6507,
#   7175,
#   3161,
#   2366,
#   1524,
#   1335,
#   4153,
#   7385],
#  [5072, 3008, 1352, 2282, 7141, 5202],
#  [5243, 5202],
#  [905, 7141, 2167, 3961, 7385, 5818, 7356, 2366, 3362, 5465],
#  [5818, 2280, 3008, 3366, 5162, 2282, 6442, 3706, 6266, 649],
#  [5243, 3706, 6266],
#  [6442, 4492, 3008],
#  [5818,
#   7356,
#   6139,
#   3008,
#   14,
#   5477,
#   3774,
#   3008,
#   3565,
#   1291,
#   7141,
#   7385,
#   4264,
#   3008,
#   5072,
#   6478,
#   14,
#   5477,
#   2282,
#   969],
#  [6952],
#  [5923],
#  [6099, 5078],
#  [4442, 5072, 2282],
#  [1821, 3008, 60, 932, 2353],
#  [6952],
#  [1742, 1821, 1445, 1997, 1445, 545, 3565, 6375],
#  [712],
#  [4121],
#  [1445,
#   1197,
#   935,
#   5383,
#   1445,
#   1081,
#   3909,
#   6647,
#   503,
#   6442,
#   7343,
#   7385,
#   5818,
#   4328,
#   4551,
#   7385,
#   1718,
#   4121,
#   1524,
#   4577,
#   1205,
#   1445,
#   1718,
#   6478,
#   2514,
#   7385,
#   4749,
#   1275],
#  [1718, 1445, 7385, 2461, 235],
#  [2365,
#   5818,
#   5072,
#   6478,
#   4472,
#   6442,
#   7385,
#   88,
#   4662,
#   5630,
#   7385,
#   6507,
#   1292,
#   2282,
#   4256,
#   7385,
#   4264,
#   7385],
#  [3774,
#   5818,
#   42,
#   2,
#   6442,
#   7053,
#   6647,
#   6507,
#   2155,
#   2282,
#   297,
#   2282,
#   1997,
#   3909,
#   2004,
#   6507,
#   6442,
#   3527,
#   6647,
#   6079,
#   297,
#   2282,
#   1997,
#   3909,
#   2004,
#   3008,
#   14],
#  [5818, 1869, 2282, 1362, 7002, 2663, 4777, 3629],
#  [3008, 4472, 3008, 1726, 7206, 6442, 4688, 7385, 2917, 6442, 4569],
#  [987, 2868],
#  [2514, 7224, 3008, 1292, 2282, 7385, 7385, 103, 4153, 3767],
#  [7224,
#   267,
#   5818,
#   1869,
#   2564,
#   6442,
#   7385,
#   7385,
#   103,
#   1292,
#   4264,
#   6442,
#   6786,
#   800,
#   2427,
#   5981,
#   1718,
#   7175,
#   1362,
#   1986,
#   4264,
#   2899,
#   5818,
#   7356,
#   1721,
#   1685,
#   1524,
#   5691,
#   1685,
#   3687,
#   782,
#   3296,
#   1824],
#  [3687, 782],
#  [6889],
#  [2659, 4467, 3954],
#  [2431, 5630],
#  [1352, 5818, 297, 2282, 325, 2282, 3008, 5416, 6442, 4569],
#  [1742, 1869, 3008, 3027],
#  [5818,
#   1869,
#   6442,
#   3229,
#   2282,
#   3944,
#   6442,
#   5202,
#   3909,
#   88,
#   3008,
#   2,
#   3008,
#   5072,
#   6478,
#   5162,
#   3909,
#   88,
#   3422,
#   2789],
#  [2326, 3422, 761, 5437, 7141, 4328, 3008, 6507, 7170, 6053],
#  [3035,
#   4723,
#   5981,
#   7385,
#   1718,
#   4286,
#   2917,
#   4259,
#   7385,
#   4264,
#   6647,
#   6507,
#   1292],
#  [2326,
#   5818,
#   6274,
#   3008,
#   739,
#   1869,
#   5557,
#   28,
#   5818,
#   5072,
#   6478,
#   14,
#   2025,
#   5818,
#   7356,
#   3303,
#   2282,
#   349,
#   1205,
#   6507,
#   3008,
#   1292,
#   2282,
#   7385,
#   7385,
#   4749,
#   3767,
#   6010],
#  [5243, 5072, 3008, 4472],
#  [3008,
#   6507,
#   3493,
#   3422,
#   7385,
#   651,
#   3008,
#   6056,
#   6478,
#   1362,
#   6053,
#   5818,
#   4043,
#   1362,
#   6053],
#  [5243, 1718, 6053],
#  [4043, 3008, 4704, 1685, 3565, 3313, 6010, 5981, 3008, 6507, 3650, 1948],
#  [2366, 5818, 7356, 2155, 2282, 14, 5243, 5981, 3063, 4723],
#  [987, 7148, 2248, 3008, 1869, 33, 88, 4717],
#  [3008, 6507, 7224, 3650, 7385],
#  [2365, 5818, 7117, 2282, 325, 2282, 3008, 5818, 7117, 2282, 5787, 3008],
#  [5818,
#   5072,
#   6478,
#   5162,
#   3008,
#   3008,
#   2929,
#   2366,
#   3008,
#   6507,
#   212,
#   3706,
#   1685,
#   7360,
#   88,
#   7141,
#   4264,
#   2899,
#   3008,
#   1997,
#   6728,
#   7385,
#   5383,
#   3008,
#   5162,
#   6375],
#  [1352,
#   5818,
#   14,
#   3008,
#   5569,
#   4090,
#   2282,
#   3821,
#   7002,
#   651,
#   5818,
#   7356,
#   6478,
#   5894,
#   2199,
#   7042],
#  [2366, 3008, 315],
#  [5818,
#   5072,
#   315,
#   1205,
#   5818,
#   7356,
#   5557,
#   1846,
#   7385,
#   2663,
#   959,
#   6242,
#   1685,
#   932,
#   4052,
#   6840,
#   6478,
#   4456,
#   7321,
#   1726,
#   4149],
#  [5630, 2236, 473, 3008, 6647, 648, 3909, 1821, 1445],
#  [5243],
#  [2663, 7385, 1685, 5557, 3318],
#  [2025],
#  [1445, 545, 2366, 5557, 4884, 100],
#  [1205, 3008, 5569, 5630],
#  [138, 5818, 5072, 2084, 2899, 545, 5557, 6292, 7310],
#  [1445, 2618, 3199, 545, 959, 3035, 7224, 5818, 1821, 3035],
#  [3008, 1821, 5243],
#  [1205],
#  [2421,
#   5981,
#   5818,
#   4694,
#   5818,
#   3366,
#   2236,
#   5072,
#   1931,
#   3565,
#   651,
#   3199,
#   7321,
#   545,
#   959,
#   3035,
#   4264,
#   5818,
#   3949,
#   307,
#   6427,
#   1685,
#   7385,
#   4749,
#   4264,
#   3422,
#   7385,
#   7385,
#   237],
#  [2025, 6119, 3008, 5787, 905],
#  [5818, 4469, 2282, 2915, 3008, 5224, 1721, 932, 4052, 2435, 5416, 4717],
#  [5981, 1718, 6478],
#  [5818, 7356, 6478, 6635, 5318, 2282, 6734, 932, 3834],
#  [5818, 4761, 5818, 6274, 5818, 545, 2067, 3008],
#  [761,
#   3008,
#   6507,
#   3565,
#   2366,
#   4717,
#   3565,
#   232,
#   905,
#   4302,
#   1442,
#   2663,
#   6442,
#   7164,
#   7224,
#   5818,
#   4043,
#   1156,
#   1931,
#   1685,
#   5465],
#  [6478,
#   4577,
#   2268,
#   6507,
#   3706,
#   2365,
#   3008,
#   4043,
#   6219,
#   5213,
#   6442,
#   4696,
#   3008,
#   297,
#   2282],
#  [3008, 6564, 639, 3794, 6010, 3008, 14],
#  [2915, 1997],
#  [3008, 6754, 905, 1721],
#  [5818, 3565, 4469],
#  [5243, 2282, 3650, 4875, 905, 2282, 6843, 905, 2282, 4737, 2742, 5243],
#  [1718, 5981, 4022, 5557, 5738, 7385, 2461, 1718, 3035, 3565, 905],
#  [6364, 1718, 5981, 5557],
#  [138,
#   5072,
#   6478,
#   5162,
#   4507,
#   4829,
#   1205,
#   4929,
#   7141,
#   1025,
#   4264,
#   5818,
#   4472,
#   1445,
#   739,
#   349],
#  [6952, 3008, 6507, 6478, 4662, 5925, 932, 4220, 2111, 4662, 191, 88, 1008],
#  [5243, 2, 6099, 2236, 2111, 4662],
#  [2899, 3154, 6056, 3008, 4264, 5818, 6056, 5162, 2282, 1808, 2917, 6010],
#  [1205, 6099, 3908, 297, 2282, 28],
#  [4829, 5818],
#  [4264, 1742, 6507, 3008, 1292],
#  [2,
#   3008,
#   2056,
#   14,
#   6647,
#   1577,
#   7385,
#   2282,
#   1997,
#   2282,
#   5557,
#   316,
#   1968,
#   3405,
#   88,
#   4700],
#  [5451, 4782, 2389, 1524, 7385],
#  [4829, 4696, 958, 905, 2282, 1362, 4525],
#  [2326, 761, 987, 7362],
#  [23, 6442, 3496, 6588, 3008, 1997],
#  [4829, 6952],
#  [3089,
#   905,
#   3008,
#   6056,
#   6478,
#   325,
#   2282,
#   7360,
#   2848,
#   644,
#   932,
#   4220,
#   1718,
#   7115],
#  [2025],
#  [4829, 5818, 297, 2282, 6381, 6442, 4569, 2004, 3008, 987, 7282, 6010],
#  [6442, 4569, 3600, 4254, 5557, 28],
#  [6952, 1205],
#  [987,
#   5981,
#   1700,
#   5592,
#   5630,
#   6389,
#   5981,
#   1726,
#   4149,
#   712,
#   3008,
#   297,
#   905,
#   2282,
#   1632,
#   3422,
#   7298,
#   1685],
#  [1445, 1718, 6478, 5557, 1700, 5592, 1424, 5981, 1718],
#  [3008, 6507, 6478, 1292, 644, 932, 4220, 6625, 191, 88, 7310],
#  [5818, 7356, 6090, 6242],
#  [6219, 5557, 6795, 7385],
#  [6119,
#   1869,
#   3008,
#   7385,
#   1685,
#   5557,
#   7385,
#   4945,
#   6762,
#   4442,
#   5557,
#   5216,
#   212,
#   7385,
#   7385,
#   2793,
#   1685,
#   3008],
#  [4945, 88, 5557, 4945, 3008, 3234, 5557, 2764, 88, 7385, 4899, 2663],
#  [2236],
#  [7385,
#   1815,
#   3313,
#   5106,
#   3911,
#   7203,
#   6442,
#   3779,
#   3313,
#   1208,
#   6876,
#   4264,
#   7385],
#  [3008, 6442, 6212, 3848],
#  [7224, 4442, 5787, 905],
#  [7224, 4555, 7385, 3008, 5325],
#  [2206, 6079, 5477, 3366, 3008],
#  [5818, 545, 6139, 4696, 6079, 6993, 4525],
#  [267, 5557, 2764, 6647, 6507, 7385, 4585, 6442, 4605, 444],
#  [5477, 2776, 4696, 1577, 2663, 932, 3509, 7042],
#  [7385],
#  [5162, 3909],
#  [5477, 2776, 4696, 1997, 6375],
#  [5981, 5818, 7356, 1856, 2282],
#  [5981, 1106, 5818],
#  [3008, 2965, 3008, 7385, 3008, 7385],
#  [712, 1718, 6099],
#  [2365, 7385, 7385, 5072, 6478, 3063, 4472, 5416, 3035],
#  [2025, 6478],
#  [2025, 5072, 1815, 2366, 5981, 6219, 2366, 7053, 2366, 5981],
#  [651,
#   4442,
#   6507,
#   7385,
#   2282,
#   614,
#   2371,
#   2273,
#   7053,
#   2366,
#   5981,
#   4264,
#   614,
#   7385,
#   6588,
#   4505,
#   614,
#   1696,
#   5942,
#   1718,
#   1640,
#   7385],
#  [1445, 6219, 1869, 5981, 7385, 7385],
#  [3008, 14, 3704],
#  [2235, 5072, 3422, 5976, 5325, 5459],
#  [4761, 712, 3565, 1603, 1721, 1685, 5557, 7385],
#  [3008, 4328, 5818, 3366, 5162, 5557, 1573, 2282, 325, 2282, 2593],
#  [267, 3565, 5557, 5636, 4300, 2004, 6442, 7385],
#  [5981, 1718, 2593, 7385, 4220],
#  [5818,
#   5395,
#   2593,
#   3704,
#   5162,
#   2282,
#   14,
#   2593,
#   7385,
#   2593,
#   2004,
#   1001,
#   4264,
#   6099,
#   3942,
#   2663,
#   1644,
#   2004,
#   905],
#  [5243, 5416, 4717],
#  [5243, 6069, 3008, 4472, 1445, 6056, 5072, 3035],
#  [1445, 2606, 2366, 1445, 7385, 4153, 5801],
#  [6952,
#   6139,
#   1445,
#   1718,
#   5557,
#   5365,
#   5818,
#   33,
#   1445,
#   5593,
#   5557,
#   3300,
#   7385,
#   4153,
#   5082,
#   1445,
#   3565,
#   2564,
#   3909,
#   88,
#   7385],
#  [4442, 6219, 2915, 7385, 3821, 2663, 4153, 7385, 7385],
#  [5818,
#   7356,
#   1714,
#   743,
#   1445,
#   1718,
#   1796,
#   1445,
#   4303,
#   1929,
#   4052,
#   2413,
#   4153,
#   6442,
#   7313,
#   3872,
#   7224,
#   1445,
#   3101,
#   6819,
#   6212,
#   7385],
#  [4704,
#   1929,
#   7008,
#   5072,
#   3008,
#   4472,
#   6647,
#   1869,
#   2564,
#   5557,
#   6554,
#   2461,
#   6478],
#  [1821, 6099, 6079, 134, 6099, 3366, 1997, 3909, 2004, 3008],
#  [3008,
#   14,
#   2,
#   3008,
#   5072,
#   1997,
#   3909,
#   2004,
#   2365,
#   3008,
#   3366,
#   1362,
#   6754,
#   3008,
#   3366,
#   7385,
#   3199,
#   5190,
#   7385,
#   2004,
#   905,
#   4585,
#   932,
#   5045],
#  [5818, 6274, 3008, 3060, 3974, 4696],
#  [3008, 2564, 4717, 3226],
#  [7141, 1718, 3035, 5557, 3603, 1552, 6364, 3818, 349, 7385, 2282, 6442, 4749],
#  [2663,
#   5981,
#   2459,
#   6647,
#   6056,
#   7117,
#   2282,
#   5224,
#   3035,
#   5557,
#   7385,
#   7061,
#   3909],
#  [6056, 7385, 5162, 428],
#  [7323, 3313, 6099, 4187, 7385],
#  [987, 5557, 7097, 6321, 7046],
#  [2593, 801, 5133],
#  [1445, 1718, 3012],
#  [7385, 932, 5971, 1685, 3313, 6010],
#  [3008, 473, 905, 5981, 4424, 2346],
#  [3850, 1494, 7385],
#  [6442,
#   3932,
#   1718,
#   5981,
#   5243,
#   6376,
#   88,
#   7385,
#   3565,
#   6768,
#   1721,
#   5557,
#   1106,
#   4264,
#   7385,
#   2593,
#   1442,
#   3928,
#   3008,
#   6507,
#   3256,
#   2282,
#   2593],
#  [7385, 7385, 1205, 2659, 3008, 6507, 755, 3686],
#  [3008,
#   1904,
#   6442,
#   4022,
#   1653,
#   354,
#   4153,
#   6442,
#   7385,
#   88,
#   1956,
#   4264,
#   3063,
#   6442,
#   1140],
#  [4264, 1445, 4723, 5981, 5190, 2663, 5557, 4562, 7385, 5178, 88, 2789],
#  [5243, 1869, 3008, 2564, 1685, 905],
#  [5078,
#   4397,
#   7385,
#   4768,
#   7385,
#   7385,
#   4264,
#   6089,
#   7385,
#   1106,
#   4277,
#   88,
#   6442,
#   7385,
#   7385],
#  [7385, 1718, 4286, 4525, 7282, 6010],
#  [3789, 5818, 7356, 5557, 5216, 5649],
#  [5243, 6507, 3008, 3256, 5416],
#  [3789, 5072, 3008, 2366, 6442, 1106],
#  [2235],
#  [5243, 3366, 3008, 5072, 2282, 2593],
#  [6099,
#   4187,
#   3008,
#   2004,
#   6442,
#   5082,
#   88,
#   5557,
#   2026,
#   7385,
#   5981,
#   1718,
#   5557,
#   2314,
#   3568],
#  [3008, 6228, 7360, 7385],
#  [6099, 1088, 905],
#  [5243, 1718, 6442, 5793],
#  [6442, 7385, 3161, 1718, 147, 3600, 3949, 3008, 3027, 3458, 932, 7385],
#  [267,
#   4264,
#   5818,
#   4479,
#   6442,
#   4688,
#   4424,
#   88,
#   3008,
#   7385,
#   2663,
#   932,
#   5719,
#   7385,
#   7207,
#   545,
#   932,
#   7385,
#   4629,
#   2457],
#  [2659, 5072, 3008, 2435],
#  [1742, 3274, 3999],
#  [1442],
#  [4196, 3422, 4220, 5266],
#  [267],
#  [2625, 6350, 4834, 5815],
#  [267, 1424, 5818, 297, 3008, 2282, 1997, 3909, 2004, 2593],
#  [2235, 7385, 5818, 6056, 5162, 6389, 4153, 3035],
#  [3008, 3565, 2618],
#  [3008, 7117, 727, 2282, 667, 5557, 1106, 3909],
#  [3008,
#   2564,
#   3035,
#   7385,
#   5818,
#   2708,
#   1721,
#   6442,
#   2479,
#   3008,
#   5072,
#   6442,
#   7385],
#  [3008, 6507, 7175, 2422, 905, 2282, 667, 3909, 7059, 1106],
#  [5818,
#   4043,
#   28,
#   2593,
#   4220,
#   5925,
#   5981,
#   3313,
#   6858,
#   5557,
#   5504,
#   4264,
#   5981,
#   1718,
#   6442,
#   128,
#   6099,
#   3908,
#   297,
#   5557,
#   5504],
#  [5818, 4043, 667, 5557, 1106, 2366, 5981, 3909, 4153, 4777, 5548],
#  [667, 3035, 2461, 4196, 3035, 7141, 1496, 5557, 7385],
#  [5383, 5818, 1451, 3909, 1458, 5818, 958, 6931],
#  [5818, 7356, 4153, 3035],
#  [2933, 6442, 37, 5347, 3422, 3126, 3908, 4607, 2389, 5557, 28],
#  [5818, 3565, 7385, 3422, 2274],
#  [5243],
#  [5557, 3842, 5548, 5557, 28],
#  [4704, 3035],
#  [987, 5416, 4502],
#  [5477, 3366, 3008, 5072, 3035],
#  [5072, 5243],
#  [5818, 5072, 6478, 14, 7385, 6442, 7385, 5553, 4705, 3842, 1685, 6442, 7385],
#  [2659],
#  [6507, 3008, 5882],
#  [4373, 3565, 1085, 4585, 2282, 6849],
#  [6647, 5072, 6478, 6849],
#  [6367,
#   6079,
#   5818,
#   6274,
#   5818,
#   3366,
#   831,
#   1524,
#   5478,
#   4585,
#   3008,
#   3008,
#   14,
#   3565,
#   2282,
#   3234,
#   2,
#   3008,
#   6507,
#   2054],
#  [1205,
#   6099,
#   4043,
#   1997,
#   3909,
#   2004,
#   3008,
#   651,
#   2593,
#   4220,
#   1718,
#   7141,
#   7237,
#   7179,
#   2459,
#   4264,
#   6952,
#   3313,
#   6056,
#   1997,
#   3909,
#   2004,
#   2593,
#   6389],
#  [5437, 7141, 1275, 1869, 5557, 6678],
#  [5818, 4630, 3008, 6507, 7385, 7385],
#  [6936, 267, 6647, 6507, 3509, 7385],
#  [3008, 4264, 7385],
#  [3008, 6260, 6478, 5067, 7141, 1721, 5818, 7356, 6661, 7385],
#  [5510, 5981],
#  [6364, 7385, 752, 7385],
#  [5981,
#   1718,
#   6131,
#   7385,
#   6442,
#   3313,
#   712,
#   545,
#   5613,
#   1685,
#   5557,
#   1198,
#   5818,
#   33,
#   1445,
#   545,
#   959,
#   4236,
#   6035],
#  [5818, 7356, 2235, 1445, 1718, 3650, 6447, 88, 959, 1931, 5981, 678],
#  [1445, 6219, 3161, 7224],
#  [7385, 4368, 433, 354, 1718, 5557, 6784, 6284, 2789, 2282, 5664],
#  [5243, 1718, 7141],
#  [5818,
#   650,
#   5981,
#   6442,
#   1432,
#   88,
#   7141,
#   3582,
#   4180,
#   6507,
#   7385,
#   7385,
#   1205,
#   6394,
#   354,
#   7224,
#   3008,
#   3818,
#   1362,
#   2004,
#   5789,
#   7148,
#   1718,
#   6058,
#   6442,
#   6255,
#   88,
#   6053,
#   7385,
#   7385,
#   3008,
#   6507,
#   7385,
#   7070,
#   7150,
#   7385,
#   325,
#   6707,
#   7385,
#   4264,
#   2193,
#   6442,
#   4686,
#   88,
#   3974,
#   712,
#   7117,
#   6784,
#   2215,
#   4737],
#  [6442, 4696, 2917, 7141, 7042, 6507, 7224, 634, 4814],
#  [7224,
#   1445,
#   4254,
#   7141,
#   1986,
#   7385,
#   3423,
#   5416,
#   2859,
#   7385,
#   4264,
#   7385,
#   5981,
#   5818,
#   1997,
#   2282,
#   1929,
#   7385,
#   7385,
#   7385,
#   1025,
#   7323,
#   3313,
#   281,
#   3350,
#   7042,
#   5818,
#   1869,
#   6952,
#   134,
#   2917,
#   4577],
#  [5789, 3366, 2236, 1869, 5613, 2282, 5557, 3300, 7042],
#  [5789, 6119, 3063, 1997, 2282, 2199, 7042],
#  [5981, 1718, 2236, 3027, 5393],
#  [5818,
#   1076,
#   932,
#   1479,
#   3843,
#   5557,
#   7385,
#   833,
#   1205,
#   5818,
#   7356,
#   7385,
#   5072,
#   3008,
#   2435],
#  [5437, 3035, 43],
#  [3008, 4472, 7141, 6056, 5963],
#  [5243, 3366, 1445, 134],
#  [3008,
#   648,
#   2282,
#   6442,
#   4749,
#   5818,
#   6274,
#   6647,
#   1577,
#   1947,
#   2773,
#   2282,
#   7385,
#   3528,
#   1730],
#  [5818, 6119, 1869, 5557, 5949],
#  [3008,
#   6119,
#   1869,
#   5557,
#   5949,
#   1742,
#   1718,
#   3600,
#   4264,
#   5243,
#   1869,
#   3008,
#   1122,
#   2004,
#   2593],
#  [5818, 1821, 2365, 5557, 1760, 4264, 3035, 7385],
#  [3008, 6119],
#  [3818,
#   3008,
#   3063,
#   7220,
#   712,
#   6442,
#   3932,
#   3366,
#   1997,
#   2282,
#   7141,
#   5557,
#   7385,
#   88,
#   6536,
#   7385],
#  [6367, 5818, 4761, 6647, 6507, 6478, 307, 6647, 5072, 6478, 1869, 309],
#  [1352,
#   2282,
#   3008,
#   3008,
#   1037,
#   2366,
#   4250,
#   4577,
#   1844,
#   3311,
#   651,
#   7385,
#   1718,
#   1990,
#   2919],
#  [5078,
#   5078,
#   6647,
#   6056,
#   6478,
#   1997,
#   987,
#   6478,
#   2366,
#   5818,
#   1869,
#   5557,
#   2712,
#   2660],
#  [3008,
#   1726,
#   7206,
#   6016,
#   2917,
#   7141,
#   5325,
#   6442,
#   146,
#   3673,
#   6647,
#   6507,
#   755,
#   5557,
#   568],
#  [1869, 3008, 1026, 4717],
#  [712],
#  [5789, 1445, 5087, 905, 2282, 7268, 4717, 6375],
#  [5818, 4328, 4022, 5477, 3274, 3425],
#  [4589, 2366, 5557, 4399, 6079, 4264, 354],
#  [4929, 5557, 2789, 2282, 5162, 5557, 6709, 3406],
#  [2708, 3008, 1721, 6505, 2899],
#  [6442,
#   6010,
#   5818,
#   667,
#   3008,
#   2282,
#   224,
#   3008,
#   1869,
#   2236,
#   3027,
#   6588,
#   4264,
#   2084],
#  [2366, 1742, 6442, 7385, 4153, 7385, 5072, 3008, 3063, 14, 3422, 6980, 7385],
#  [3008, 5569, 905, 5072, 6478, 3008],
#  [5818, 5072, 6478, 3620, 4472, 3008, 143, 5981, 3464, 1524, 3087],
#  [2899, 134, 3008, 6056, 3761, 5305, 6010, 2917, 6442, 5246, 2004, 905],
#  [4264, 2025, 3366, 5818, 5072, 5981],
#  [4899,
#   4153,
#   6442,
#   7385,
#   6442,
#   4789,
#   5825,
#   3008,
#   2004,
#   727,
#   2663,
#   932,
#   2277,
#   905,
#   2004,
#   3422,
#   5024,
#   4153,
#   932,
#   5979],
#  [3008, 5829, 2663, 3422, 1598],
#  [6507, 3008, 920, 905],
#  [5818,
#   545,
#   2663,
#   6442,
#   7385,
#   5818,
#   1820,
#   932,
#   3126,
#   6274,
#   5818,
#   3366,
#   134,
#   2431],
#  [3008, 6507, 6478, 5557, 5719, 7385, 6507, 3008],
#  [2659, 4121, 6707, 6972],
#  [3990, 905],
#  [5981, 1718, 5243, 3008, 297, 1496, 3035],
#  [3008,
#   14,
#   1399,
#   7053,
#   6507,
#   6952,
#   7385,
#   6422,
#   2461,
#   6442,
#   7385,
#   1205,
#   4442,
#   6507,
#   6389,
#   1721,
#   4525],
#  [3008, 14, 712, 6442, 7385, 6507],
#  [5243, 1718, 7141],
#  [5818,
#   7356,
#   7290,
#   7385,
#   743,
#   1496,
#   5981,
#   5243,
#   3008,
#   6507,
#   2155,
#   2282,
#   5072,
#   2917,
#   5557,
#   4749],
#  [5818, 134, 5072, 5243, 3008, 1981, 5072],
#  [5078],
#  [3008, 6507, 6478, 5078],
#  [5818, 3565, 7117, 2282, 3082, 2218, 1685, 6416],
#  [6936, 6936, 3008, 3082, 2218, 4264, 3008, 6056, 1997, 2282, 1808],
#  [5818, 14, 3565, 2915, 905, 1808],
#  [7141, 1718, 7224, 7385],
#  [4196, 3035, 2282, 3008, 2282, 321, 5719, 7113, 5383, 3008, 6507, 7385],
#  [2025, 6507, 3008, 959, 7141],
#  [5818, 473, 3008],
#  [3008, 5072, 6478, 315, 2, 5818, 5664],
#  [2235, 5818, 5072],
#  [2025],
#  [651, 2899, 5818, 3366, 1869, 2282, 4766, 1990, 3909, 1815, 712, 2366, 905],
#  [2366, 3008, 3101, 3181, 3313],
#  [3234, 5981, 712, 3594, 161, 5383, 5818, 1869, 2564, 1277, 882],
#  [2025, 3366, 3008, 2915, 4717, 5162, 2282, 3008],
#  [712],
#  [7385],
#  [5818, 5569, 4717],
#  [5818,
#   14,
#   3035,
#   3366,
#   1869,
#   2282,
#   1362,
#   5557,
#   3012,
#   5719,
#   4714,
#   2282,
#   5162,
#   3008,
#   2282,
#   7385,
#   7385,
#   3008,
#   5072,
#   6478,
#   5399,
#   2366,
#   6442,
#   5178],
#  [2659,
#   743,
#   3008,
#   336,
#   1726,
#   937,
#   4472,
#   5818,
#   3818,
#   1362,
#   6100,
#   3008,
#   5072,
#   6478,
#   4472,
#   5818,
#   3818,
#   1362,
#   5505,
#   2084,
#   2366,
#   3199,
#   7321],
#  [5818, 6274, 3008, 1577, 3574, 4577, 5981],
#  [3600, 5100, 1721],
#  [4264, 5818, 7356, 2663, 2895, 88, 3035],
#  [5383, 3008, 1577, 5613, 3794, 1198, 1742, 1577, 3008],
#  [5649],
#  [1577, 3008, 2663, 3427],
#  [2248],
#  [6952, 3008, 3564],
#  [2899, 2025, 3366, 3008, 349],
#  [5818, 4561, 5072, 7141],
#  [5072, 5243],
#  [4766, 5557, 6436],
#  [3422, 1096, 6683, 3753, 88, 5981, 5981],
#  [2326, 7224, 138, 3008, 4472, 3008, 14, 905],
#  [7224,
#   5243,
#   1726,
#   4149,
#   1721,
#   2004,
#   932,
#   863,
#   1445,
#   5557,
#   2832,
#   2663,
#   6442,
#   5979],
#  [1445, 3565, 431, 905, 2282, 1362, 4456, 5818, 7356, 6478],
#  [712],
#  [2365],
#  [3990, 905, 1869, 3008, 1026, 6442, 7385, 7385, 5818, 5882, 3422, 5118],
#  [5243, 6507, 3008, 959, 6375],
#  [5818, 33, 4525, 545, 5557, 3788, 3458],
#  [3008, 6507, 7224],
#  [7385],
#  [7385],
#  [7385, 5818, 4761, 4456, 2696, 4254, 2593, 4032, 2663, 5557, 1141],
#  [5072,
#   6478,
#   1685,
#   3313,
#   6950,
#   4472,
#   5981,
#   3008,
#   503,
#   7360,
#   1226,
#   1618,
#   4153,
#   3422,
#   4032],
#  [7224, 5243, 1821, 5818, 1869, 1524, 1226, 4153],
#  [1445, 4602, 5818, 7385, 6442, 7385, 4264, 1445, 7385, 4153, 905],
#  [5818, 4761, 5818, 2236, 473, 3008, 5818, 7356, 2522, 88, 4345],
#  [1169, 987, 6478, 5981, 2582],
#  [1960, 932, 6389, 1873, 4525],
#  [4704, 3035, 5818, 7356, 791],
#  [3008, 297, 905, 2282, 1623, 1721, 4264, 6707, 3008, 5477, 2282, 5162, 2218],
#  [6442, 7385, 7182],
#  [5818,
#   2280,
#   3035,
#   503,
#   2282,
#   1362,
#   6242,
#   1586,
#   2282,
#   2458,
#   932,
#   5479,
#   4264,
#   1901,
#   3008,
#   3311],
#  [3706, 6602],
#  [7224, 5477, 3366, 3008, 5162, 7385, 2282, 3161, 6442, 3779, 2789],
#  [5557, 4718, 5045, 712, 4711],
#  [267, 6367, 5072, 6478, 2915, 3035, 5162, 3909],
#  [7224, 5243, 1718, 932, 3990],
#  [34, 6442, 2789, 6647, 5072],
#  [4619],
#  [5818,
#   5072,
#   6478,
#   2366,
#   2282,
#   5072,
#   5243,
#   4696,
#   958,
#   2899,
#   4442,
#   958,
#   3035,
#   4577,
#   6442,
#   4502,
#   4264,
#   4442,
#   5162,
#   5567,
#   5383,
#   3008,
#   60],
#  [7224, 2, 3008, 3651, 4505, 5325, 6442, 4766, 3008, 6507, 5829],
#  [6242, 2366, 5981],
#  [2899, 3008, 2120, 1721],
#  [5477],
#  [3008, 1721, 1685, 3035],
#  [3300, 7385],
#  [7385],
#  [6442, 899],
#  [7385],
#  [5787, 905, 6242, 4237],
#  [5818, 5569, 7385],
#  [6952, 6242, 4492, 6242, 6952, 3313, 7321, 4131],
#  [3008, 6507, 4467, 4264, 1587, 4264, 3650, 1700, 1685, 905],
#  [5243],
#  [6952, 3313, 7321, 4131],
#  [3008, 6507, 7385, 7385, 4254, 4437, 6676, 473, 3008, 5981],
#  [1718, 5981, 5557, 2697, 2461, 5557, 587],
#  [3008, 14, 5243, 5818, 4328],
#  [6952],
#  [6952, 5243],
#  [6952, 5818, 6056, 6478, 1997, 2004, 3008],
#  [2025, 6478],
#  [6013, 5557, 5216, 1258, 4766, 5557, 6212, 3136, 5243],
#  [7224, 5818, 1869, 2282, 1869, 5557, 612, 2282, 1362, 2004, 3008],
#  [3008, 5787, 905],
#  [3008, 7117, 4737, 4254, 4437, 6676, 473, 3008, 5981],
#  [500, 6442, 6987, 6364],
#  [5477, 3366, 3008, 5162, 5557, 7385, 2917, 6442, 3794, 6950],
#  [987, 7385, 1929, 28, 2564, 4295, 1742, 3366, 3008, 5162, 6442, 2712],
#  [987, 3565, 6242, 5818, 503, 3008, 14],
#  [2326, 6972],
#  [3422, 7385],
#  [5243],
#  [5981, 1726, 4149, 3650, 1032],
#  [6233, 5818],
#  [3008,
#   1577,
#   1780,
#   2282,
#   667,
#   905,
#   3909,
#   4585,
#   6442,
#   3313,
#   1681,
#   5818,
#   5001,
#   5569,
#   5818,
#   4711,
#   3035,
#   545,
#   5557,
#   2478],
#  [3035, 4463, 2366, 5981],
#  [3620,
#   5243,
#   545,
#   3035,
#   2366,
#   5557,
#   2218,
#   4835,
#   138,
#   2899,
#   5557,
#   2805,
#   1685,
#   1485,
#   2004,
#   905],
#  [5557, 7385, 7385, 3008, 2906, 7141],
#  [6886,
#   5818,
#   503,
#   7059,
#   1335,
#   3878,
#   7059,
#   2232,
#   1780,
#   905,
#   2282,
#   667,
#   3909,
#   5557,
#   3620,
#   4121,
#   1106],
#  [1718, 5981, 6389],
#  [2025, 1718, 3422, 7385, 3254, 6442, 4688, 4661, 2804, 4153, 7141, 7385],
#  [651, 5818, 2366, 2282, 6291, 3008],
#  [2326, 2365, 3818, 3008, 5162, 905, 3422, 7385, 7385],
#  [5818, 14],
#  [5818,
#   6274,
#   6647,
#   158,
#   3008,
#   1577,
#   1292,
#   2282,
#   7042,
#   6375,
#   2917,
#   6270,
#   88,
#   7385],
#  [7141, 5325, 4456, 7147, 1499, 1718, 5003, 2282, 801, 7385, 1413],
#  [3422, 5189, 5437, 6478, 5159, 1572],
#  [2899, 5787, 4505, 5818, 503, 5557, 7385],
#  [1718, 7141, 5416, 2859, 7385, 3008, 7385, 905],
#  [5818, 6274, 3008, 1577, 7385, 905],
#  [2025, 4043, 6647, 6481, 4153, 7141],
#  [651, 3008, 6507, 755, 6480, 1685, 905],
#  [2389, 5557, 5538, 5981, 1718, 3422, 6389],
#  [7224, 5243, 5818, 297, 3908, 43],
#  [3008,
#   6507,
#   328,
#   3008,
#   5072,
#   6478,
#   14,
#   5243,
#   3008,
#   297,
#   3008,
#   6056,
#   6478,
#   14,
#   5925,
#   3008,
#   6507,
#   511,
#   4264,
#   3008,
#   5072,
#   6478,
#   1869,
#   3035],
#  [545, 5981, 932, 4220],
#  [267, 6099, 4602, 2004, 7059, 7385, 5719, 3527, 1957, 88, 6022],
#  [5818,
#   5072,
#   6478,
#   7118,
#   6442,
#   7385,
#   88,
#   7385,
#   4768,
#   1718,
#   7141,
#   6242,
#   5818,
#   4561,
#   1362,
#   1065,
#   2282],
#  [6952, 4829],
#  [7224, 5787, 905, 5416, 7141, 5176, 545, 3035, 723],
#  [6373, 88, 3035],
#  [4555, 6373],
#  [6442, 4424, 1742, 2365, 2307, 6442, 3932, 3909, 88, 7059, 3848],
#  [2365, 1821, 5243],
#  [5243, 1718, 6442, 43, 4507, 5981, 5818, 7385, 3311, 4153, 2593],
#  [3008,
#   14,
#   4051,
#   5072,
#   6478,
#   2366,
#   2282,
#   2100,
#   5981,
#   614,
#   3785,
#   6507,
#   3797,
#   88,
#   6975,
#   614,
#   4052,
#   7244,
#   3035,
#   4723,
#   6647,
#   1869,
#   1291,
#   7385,
#   2365,
#   2696,
#   5411,
#   905,
#   5682,
#   5557,
#   3443,
#   7385,
#   3008,
#   1869,
#   503,
#   905,
#   4153,
#   6442,
#   7385,
#   1685,
#   5502,
#   5383,
#   3008,
#   1997,
#   2282,
#   2859,
#   7385,
#   5818,
#   6056,
#   6478,
#   3063,
#   1362,
#   2020,
#   2282,
#   4593,
#   6442,
#   5885],
#  [5383, 5818, 1997],
#  [7385, 7385, 3422, 3422, 3008, 1869, 3027, 7385, 7044, 7385, 6974],
#  [7385, 3422, 2941, 1718, 6478, 5557, 2447, 4054],
#  [6367,
#   4619,
#   3023,
#   2282,
#   932,
#   3779,
#   2855,
#   88,
#   3259,
#   7141,
#   1198,
#   148,
#   5458,
#   6507,
#   1798,
#   7385,
#   4585,
#   6442,
#   2789,
#   1116,
#   7385,
#   7385,
#   3874,
#   3754,
#   648,
#   1798,
#   6367,
#   2663,
#   2459,
#   3008,
#   6507,
#   2054],
#  [5818,
#   2696,
#   5155,
#   5981,
#   1445,
#   619,
#   7149,
#   2663,
#   6442,
#   3964,
#   5818,
#   545,
#   5754,
#   5557,
#   7385],
#  [7385],
#  [7356,
#   5818,
#   2155,
#   2282,
#   10,
#   6260,
#   2366,
#   6389,
#   138,
#   2461,
#   5072,
#   5818,
#   1869,
#   7059,
#   4502,
#   2282,
#   4472,
#   5416,
#   3035],
#  [2659, 4525, 1600, 88, 2640],
#  [2431],
#  [6100, 127, 3008, 5557, 4945],
#  [3008, 4472],
#  [7385, 6389],
#  [6389],
#  [3600, 5557, 4945, 212],
#  [134, 3035],
#  [5243],
#  [5243, 6554],
#  [6442,
#   3662,
#   1718,
#   3422,
#   743,
#   3789,
#   6375,
#   4254,
#   5557,
#   6681,
#   4219,
#   1685,
#   2365,
#   7385],
#  [5818,
#   4472,
#   5818,
#   6493,
#   7385,
#   5383,
#   5818,
#   134,
#   5981,
#   7385,
#   1644,
#   1718,
#   4744,
#   7385,
#   5369,
#   134,
#   5630,
#   7385],
#  [5981, 1718, 1742, 6647, 3818, 3061, 3008, 2004, 3600],
#  [7224, 7385, 3818, 5162, 6442, 1106],
#  [3008, 2625, 6507, 7175, 3061, 905, 7385, 6442, 2779, 1050],
#  [5243],
#  [6507, 3008, 360, 905, 5818, 7356, 5557, 7385],
#  [6676, 3027, 2282, 4259, 7385],
#  [5818,
#   2561,
#   2282,
#   4472,
#   88,
#   3035,
#   3495,
#   2389,
#   1524,
#   3664,
#   2282,
#   5243,
#   6442,
#   7139,
#   4666],
#  [7224, 3008, 2564, 140, 2004, 6099, 712, 7385],
#  [3008, 1577, 6389, 6099, 1718, 2696, 1844],
#  [4467, 1644, 7385, 1698, 1890],
#  [5818, 2903, 3008],
#  [3035, 6991, 6375, 3008, 6276, 354, 2282, 5557, 3405, 88, 7385, 1815],
#  [3035, 545, 5557, 7385, 5818, 545, 248, 1777],
#  [5818,
#   5072,
#   6478,
#   7118,
#   6364,
#   3008,
#   3949,
#   1122,
#   1931,
#   7385,
#   7141,
#   1824,
#   6507,
#   3008,
#   6478,
#   1542,
#   6367],
#  [2437, 88, 6442, 5652],
#  [2025, 5072, 6478, 6647, 6381, 932, 6408, 7117, 2282, 1362, 5557, 7385],
#  [5243, 1718, 2282, 6381],
#  [3008,
#   3564,
#   7385,
#   3008,
#   6762,
#   6635,
#   4264,
#   2389,
#   7070,
#   2389,
#   5818,
#   3818,
#   5787,
#   3008,
#   6507,
#   4688,
#   2002,
#   4076,
#   7224,
#   2025,
#   1718,
#   3035,
#   5981,
#   3008,
#   6507,
#   2045,
#   5557,
#   7385],
#  [3008, 6507, 3650, 7385],
#  [2663, 6442, 3273],
#  [5243, 1718, 5557, 7385, 1685, 7385],
#  [753, 3818, 5557, 743, 3063, 3207, 5557, 5858, 6588, 3008, 3141, 4766, 7385],
#  [7385],
#  [3366,
#   3008,
#   3894,
#   1362,
#   7385,
#   4585,
#   5557,
#   4323,
#   2461,
#   5557,
#   2795,
#   3840,
#   7109],
#  [4442,
#   6056,
#   5176,
#   4442,
#   6056,
#   5686,
#   4442,
#   6056,
#   4899,
#   7002,
#   2915,
#   2593,
#   1997],
#  [5243,
#   5072,
#   3008,
#   1981,
#   4593,
#   6647,
#   1869,
#   2564,
#   5202,
#   5202,
#   5202,
#   2461,
#   5202],
#  [1869, 5557, 4121, 4502, 5591],
#  [5243, 3565, 6396],
#  [932, 3785, 648, 2282, 6442, 4569],
#  [1821, 5818, 1869, 1931, 2282, 134, 5416, 3035],
#  [4275, 6478],
#  [5818, 2236, 1026, 2116, 2366, 7141, 6478, 3063, 2663, 2972, 7385],
#  [6442, 7385, 1292, 7385, 2663, 6442, 7385],
#  [5243, 6507, 3008, 6215, 2282, 980, 5979],
#  [6820, 4196, 4717, 5266, 1445, 1718, 959, 6952, 4377],
#  [1445, 1718, 6442, 625, 2445],
#  [6647, 4561, 1869, 1026, 3437],
#  [6647, 4602, 1283, 2403, 7106, 7385, 4043, 1362, 5981, 1648],
#  [3008, 134, 898, 3818, 1362, 1081, 4585, 704, 7091],
#  [4619,
#   932,
#   7385,
#   6442,
#   5512,
#   4561,
#   6478,
#   667,
#   2868,
#   5369,
#   3284,
#   2461,
#   1913,
#   2403],
#  [1107,
#   336,
#   7385,
#   5981,
#   1718,
#   5332,
#   1742,
#   6223,
#   3958,
#   7385,
#   6507,
#   3008,
#   4861,
#   2004,
#   6442,
#   5963,
#   88,
#   7385,
#   7385,
#   7385],
#  [5818, 7356, 932, 7385],
#  [7385,
#   7385,
#   1524,
#   5183,
#   344,
#   2045,
#   2389,
#   354,
#   6056,
#   7118,
#   6223,
#   7071,
#   2004,
#   6442,
#   492,
#   5818,
#   7356,
#   6478,
#   4854,
#   2282,
#   1869,
#   4153,
#   3422,
#   5977,
#   6442,
#   7146,
#   88,
#   1432,
#   712,
#   3366,
#   1869,
#   7385,
#   5046,
#   6223,
#   3741],
#  [932,
#   7385,
#   4525,
#   1718,
#   4688,
#   3313,
#   2789,
#   2282,
#   853,
#   6442,
#   43,
#   4264,
#   5981,
#   1718,
#   2282,
#   5224,
#   6442,
#   5623,
#   5818,
#   7356,
#   537,
#   2282,
#   6187,
#   3422,
#   1267,
#   2282,
#   3001,
#   3035,
#   4027],
#  [932, 1267, 4264, 5981, 88, 62],
#  [1400,
#   932,
#   3702,
#   6384,
#   2282,
#   7385,
#   70,
#   6442,
#   3070,
#   88,
#   1160,
#   1718,
#   3313,
#   88,
#   6442,
#   7194,
#   88,
#   6442,
#   4686,
#   3063,
#   6442,
#   7385,
#   5771,
#   6507,
#   7385,
#   2004,
#   487],
#  [1718, 5981, 4577, 5981, 6042, 3008, 487],
#  [2,
#   761,
#   3698,
#   6223,
#   7385,
#   2282,
#   898,
#   5072,
#   3008,
#   1699,
#   1445,
#   3366,
#   1869,
#   1706,
#   1685,
#   3008,
#   2282,
#   6707,
#   3035,
#   2282,
#   6442,
#   4686],
#  [5072, 6478, 3008, 650, 932, 7113, 3101, 1362, 4197, 7385],
#  [898, 3818, 1362, 1081, 2282, 6442, 7091, 4264, 5818, 6056, 3001, 3035],
#  [6442,
#   3300,
#   4254,
#   7059,
#   1770,
#   2282,
#   1362,
#   2054,
#   2663,
#   7141,
#   1437,
#   4948,
#   932,
#   7385],
#  [6442, 3741, 1718, 6468],
#  [1445,
#   1718,
#   5557,
#   7385,
#   1821,
#   1445,
#   6478,
#   2346,
#   6618,
#   2282,
#   6585,
#   6442,
#   1724,
#   88,
#   7385,
#   88,
#   1929,
#   3393,
#   2927],
#  [3035,
#   6056,
#   6478,
#   1362,
#   1036,
#   2282,
#   5162,
#   4549,
#   88,
#   932,
#   7385,
#   138,
#   336,
#   7385],
#  [3008, 3818, 3234, 1685, 354],
#  [5243, 5557, 6471, 5243, 5557, 6841, 88, 5557, 1267],
#  [5818, 3101, 1362, 5613, 1685, 5502],
#  [5818, 14],
#  [5818, 3949, 5802, 3008, 894, 88, 5557, 1267],
#  [6367,
#   5981,
#   1718,
#   4237,
#   5818,
#   1869,
#   5557,
#   2445,
#   4585,
#   5557,
#   743,
#   712,
#   6056,
#   6478,
#   3489,
#   905,
#   5510,
#   6219,
#   1938],
#  [6507, 6647, 1292, 2282, 366],
#  [4563, 5818, 545, 2236, 4321, 2282, 6993, 2004, 5557, 4022],
#  [6099, 2618, 4619],
#  [5818, 7356, 6478, 7152, 3008, 2282, 5228, 2282, 1931],
#  [5818, 5072, 6478, 297, 3008, 2282, 6233, 1685, 905],
#  [7385, 5818, 297, 2282, 349, 3008, 6242],
#  [3008, 5072, 6478, 1565, 349],
#  [761,
#   3008,
#   6507,
#   7224,
#   639,
#   5818,
#   4043,
#   1699,
#   6952,
#   3779,
#   743,
#   4254,
#   6676,
#   5863,
#   3008,
#   1442,
#   5325,
#   905],
#  [4442, 6353, 6560],
#  [4043, 3008, 2572, 2004, 5343, 5557, 5216],
#  [5243, 1718, 3035, 138, 5787, 905],
#  [5818,
#   7118,
#   5981,
#   3008,
#   6056,
#   5086,
#   1362,
#   7385,
#   7385,
#   1685,
#   6442,
#   6850,
#   1718,
#   3035,
#   6478,
#   7224],
#  [5928, 905, 336, 7385, 3974, 178, 1869, 2346, 3027, 5863],
#  [4402, 5818, 349, 4585, 274],
#  [336, 7385, 4201, 7385],
#  [3422, 6879, 88, 6423],
#  [6423, 2282, 5243],
#  [7385, 88, 6442, 7091, 7385],
#  [5477, 7070, 5325, 6375],
#  [5818,
#   7356,
#   6478,
#   5557,
#   7385,
#   1205,
#   5818,
#   33,
#   3035,
#   1718,
#   6952,
#   2868,
#   5369,
#   5557,
#   1824,
#   2917,
#   693,
#   5818,
#   4914,
#   3008,
#   6507,
#   6478,
#   212,
#   5567],
#  [5477,
#   3101,
#   5818,
#   1362,
#   6442,
#   1513,
#   4254,
#   3027,
#   1081,
#   2514,
#   2389,
#   5818,
#   2618,
#   3035,
#   3366],
#  [5818, 297, 2282, 1997, 2004, 3008],
#  [4525, 6056, 1362, 5557, 4502],
#  [5072, 3008, 5228, 4153, 4577, 6442, 5812, 6403, 2663, 1274],
#  [5818, 1869, 2282, 6794, 6442, 1513],
#  [5477, 6507, 3008, 1542, 7385],
#  [1096],
#  [5243, 6507, 3008, 6215, 2282],
#  [5243, 5437, 1445, 134],
#  [1445, 6084, 5383, 1445, 3818, 4899, 2282, 581, 3008, 1445, 4602, 1929, 6932],
#  [5818,
#   297,
#   3008,
#   2282,
#   5787,
#   905,
#   6560,
#   3008,
#   3342,
#   1096,
#   5325,
#   6442,
#   1538,
#   6560],
#  [3620, 761, 5818, 6683, 14, 1742, 2282, 4766, 4264, 1157],
#  [6952],
#  [6952],
#  [5818,
#   1222,
#   3008,
#   7385,
#   7385,
#   5981,
#   3008,
#   6507,
#   2663,
#   6952,
#   5262,
#   2282,
#   4308,
#   2004,
#   905],
#  [5818, 7356, 6478, 7385],
#  [4264,
#   1577,
#   3008,
#   2236,
#   2536,
#   3702,
#   2461,
#   1718,
#   3875,
#   4688,
#   5557,
#   7225,
#   4353,
#   6442,
#   7385,
#   5557,
#   1697,
#   1685,
#   6442,
#   7191,
#   88,
#   5343],
#  [4442,
#   5072,
#   6478,
#   3234,
#   3859,
#   2663,
#   614,
#   7385,
#   4442,
#   6993,
#   6384,
#   2282,
#   976,
#   2663,
#   5557,
#   2236,
#   6901,
#   5442,
#   6442,
#   6850,
#   6507,
#   5829,
#   2004,
#   7368,
#   2090,
#   2004,
#   7385,
#   4264,
#   7385,
#   4264],
#  [3008, 3892, 354, 7385],
#  [1205, 6647, 5072, 1869, 5557, 1727, 88, 7385, 3008, 4561, 3122, 3422, 245],
#  [336, 7385, 1718, 2346, 5557, 6651, 3422, 4228, 336, 7385],
#  [3008, 5399, 2282, 1869, 5557, 5484, 2817, 1685, 755, 4700],
#  [5243, 5072, 5818, 1869, 7224, 2776, 2346],
#  [4577, 5818, 1869, 2282, 5072, 1718, 6602, 6442, 5134],
#  [5818, 7356, 6478, 2522, 88, 3008, 3008, 6507, 3088, 1205, 5557, 7385],
#  [5243, 5072, 3008, 3234],
#  [7385, 7385, 7385, 7385],
#  [134, 6478, 6375, 4289],
#  [5243, 1718, 3035, 5557, 5236, 1524, 2744],
#  [3008, 4899, 3008, 6493, 105],
#  [5787, 6442, 85, 6647, 77, 4717],
#  [85, 4131],
#  [85, 6991, 5477, 2776],
#  [751],
#  [2282, 2261, 6442, 5604, 88, 761],
#  [85, 6991, 1445, 4254, 5557, 761],
#  [4264, 4281, 2282, 2261, 1038],
#  [85, 6991],
#  [6647,
#   6056,
#   5963,
#   2004,
#   1929,
#   4696,
#   6647,
#   297,
#   3275,
#   349,
#   6442,
#   85,
#   2,
#   1445,
#   7248],
#  [1445, 7248],
#  [3008, 1869, 2282, 3181, 4505, 7385, 3161, 5243, 4442, 1821],
#  [7385,
#   6056,
#   6478,
#   3008,
#   6493,
#   2282,
#   905,
#   3008,
#   1856,
#   2282,
#   14,
#   5477,
#   2282,
#   6493,
#   2282,
#   905],
#  [3809,
#   1718,
#   5557,
#   2049,
#   1025,
#   5557,
#   6795,
#   2282,
#   5395,
#   1205,
#   7224,
#   1714,
#   5032,
#   4561,
#   1362,
#   5486,
#   780,
#   7385,
#   3063,
#   5032,
#   5325,
#   6292,
#   2371],
#  [761, 5981, 1718, 2663, 5557, 1824],
#  [5981, 1718, 5243, 3035, 6991],
#  [5477, 1821, 3008, 126, 3035],
#  [2025, 5072, 3008, 4734, 2282, 49, 7091],
#  [5477,
#   3818,
#   3008,
#   1362,
#   7224,
#   5129,
#   6442,
#   3732,
#   1718,
#   2618,
#   2282,
#   1362,
#   7385],
#  [2498,
#   5818,
#   1699,
#   6442,
#   7385,
#   6507,
#   6952,
#   2868,
#   5369,
#   7385,
#   6146,
#   7091,
#   88,
#   6442,
#   7385,
#   6850],
#  [5477, 3818, 3008, 1362, 7224, 5129],
#  [6442, 7385, 88, 7385, 7385, 4201, 7385, 7385],
#  [7385, 1718, 5557, 2747],
#  [2625,
#   3629,
#   4264,
#   2346,
#   3008,
#   6507,
#   5557,
#   7188,
#   743,
#   5072,
#   6478,
#   2915,
#   6309,
#   7385,
#   3008,
#   7385],
#  [5818, 6056, 6618, 2282, 3342, 5981, 7385],
#  [1096, 7385],
#  [6309, 1718, 6242, 3313, 4043, 2895],
#  [3008, 5162, 7224, 948, 1442, 5383, 3008, 6507, 6628, 7385],
#  [5818, 1869, 3027, 7385, 4577, 3422, 1267, 5862],
#  [3008, 2132, 6172, 2789, 2282, 7385, 3008, 2056, 6233],
#  [6233,
#   5818,
#   1869,
#   1706,
#   1913,
#   5502,
#   2346,
#   5477,
#   894,
#   1838,
#   5072,
#   3008,
#   297,
#   905,
#   2282,
#   6233],
#  [2, 761, 7385, 3008, 2282, 1997, 2899, 3008, 6056, 1997],
#  [7385],
#  [4577, 88, 4505, 3565, 452],
#  [2663, 7385, 7385, 2494, 7385, 2494, 7385, 7385],
#  [5818, 7356, 6215, 3422, 1416],
#  [1096,
#   5818,
#   1869,
#   2548,
#   3422,
#   7182,
#   5818,
#   2548,
#   3422,
#   1432,
#   4264,
#   5818,
#   2548,
#   3008],
#  [5243, 6507, 3008, 3173],
#  [5818, 6521, 6442, 5623, 6056, 1362, 1838, 5369, 5818, 2618],
#  [5477, 772],
#  [4402, 761, 5928, 3008, 3008, 2056, 5787, 4505, 3008, 2056, 5787, 932, 1432],
#  [2,
#   5818,
#   5787,
#   4505,
#   4442,
#   6056,
#   6478,
#   2364,
#   905,
#   3008,
#   14,
#   5981,
#   5818,
#   7356,
#   6389,
#   1096,
#   3008,
#   5213,
#   905],
#  [3422,
#   1416,
#   3422,
#   1416,
#   932,
#   7385,
#   6507,
#   3774,
#   677,
#   7385,
#   3008,
#   2056,
#   6493,
#   2282,
#   4505,
#   4264,
#   2,
#   3008,
#   5072,
#   6478,
#   5818,
#   6056],
#  [5818, 2878, 2663, 3008],
#  [5818, 2971, 6647, 6507, 1434, 3509, 1432, 138],
#  [5818, 1869, 2282, 953],
#  [5818, 4711, 3008, 3366],
#  [6212, 4954, 6013, 6212, 4696],
#  [2326, 7224, 3008, 6507, 5557, 6212, 743],
#  [5818,
#   4561,
#   6478,
#   3063,
#   1362,
#   6215,
#   2282,
#   3008,
#   307,
#   3422,
#   7064,
#   2618,
#   6952,
#   1205,
#   7385,
#   1612,
#   905,
#   3008,
#   6507,
#   5557,
#   743,
#   88,
#   3325,
#   4264,
#   7385,
#   4264,
#   7385,
#   5981,
#   3008,
#   6507,
#   6478,
#   5557,
#   5534],
#  [6442, 3732, 1718, 7385],
#  [5243, 1821, 4442, 134, 5416, 7385, 6588, 6275],
#  [5818, 4043, 4212, 6442, 7385, 88, 3422, 7064],
#  [4402, 5818, 6493, 7385],
#  [3008, 6707, 6952, 7385, 2282, 6493, 5451],
#  [5818,
#   14,
#   5243,
#   5818,
#   3234,
#   5818,
#   3234,
#   4456,
#   712,
#   3908,
#   4310,
#   6442,
#   4686,
#   2389,
#   3035,
#   1718,
#   5510,
#   6478,
#   2522,
#   5818,
#   3234,
#   5557,
#   3141,
#   712,
#   3024,
#   5243,
#   2],
#  [5477, 3509, 6507, 3008, 7385, 7385],
#  [5072, 4442, 1869, 2045, 2815],
#  [1205,
#   6230,
#   932,
#   5032,
#   2089,
#   6507,
#   3008,
#   2282,
#   5918,
#   2282,
#   7385,
#   7385,
#   2461,
#   7360,
#   88,
#   6442,
#   3779,
#   7385,
#   3008,
#   4402,
#   6794,
#   6442,
#   7385],
#  [77, 3008],
#  [4525,
#   1718,
#   3313,
#   103,
#   5818,
#   3366,
#   2366,
#   2282,
#   7118,
#   2025,
#   5072,
#   3008,
#   297,
#   2282,
#   1997,
#   2084,
#   2421,
#   4577,
#   7141],
#  [4264,
#   3008,
#   134,
#   7141,
#   1718,
#   1524,
#   6960,
#   1512,
#   4585,
#   761,
#   5818,
#   5072,
#   6478,
#   3234,
#   7360,
#   6376,
#   88,
#   6795,
#   5981,
#   3366,
#   5224,
#   7141,
#   5557,
#   3859],
#  [6647, 5882, 2823, 4700, 6647, 6056, 6957, 7141, 2663, 5357],
#  [3008,
#   297,
#   5557,
#   75,
#   3582,
#   6647,
#   6507,
#   5557,
#   2026,
#   4442,
#   7385,
#   5343,
#   4585,
#   6918,
#   712,
#   6056,
#   3008,
#   6422,
#   4555,
#   5236],
#  [6647, 5072, 6478, 7117, 2282, 14],
#  [6647, 4043, 6324, 6442, 4357, 6230, 3035],
#  [336, 7385, 6647, 4577, 1869, 2282, 5963],
#  [2663,
#   3313,
#   2929,
#   88,
#   7385,
#   3008,
#   1869,
#   3420,
#   5283,
#   7385,
#   712,
#   1577,
#   1885,
#   4864,
#   3779,
#   6507,
#   138,
#   7269,
#   4584,
#   5632,
#   5343,
#   4577,
#   5981,
#   651,
#   88,
#   932,
#   5365,
#   7385],
#  [7385, 1718, 5243, 1751, 7118],
#  [3008,
#   6056,
#   1362,
#   1216,
#   2663,
#   7385,
#   7385,
#   88,
#   932,
#   7385,
#   4264,
#   7385,
#   5925,
#   3008,
#   6507,
#   6469,
#   2282,
#   332,
#   1742,
#   3008,
#   6056,
#   1362,
#   7385,
#   1869,
#   3008,
#   1931,
#   2282,
#   134],
#  [2177, 7091, 344, 7385, 4264, 4402, 761, 1362, 2004, 5343],
#  [6367,
#   987,
#   6442,
#   1432,
#   5212,
#   4442,
#   42,
#   5477,
#   3008,
#   14,
#   6223,
#   5262,
#   6647,
#   1869,
#   5882,
#   2182,
#   5325,
#   3437,
#   2897,
#   7106],
#  [4264, 5243, 5072, 3008, 4472, 7385],
#  [6367,
#   5818,
#   3762,
#   14,
#   5243,
#   5557,
#   7385,
#   1718,
#   1205,
#   5818,
#   1869,
#   2236,
#   1026,
#   3035,
#   1856,
#   2917,
#   6010,
#   6588],
#  [5243, 5072, 3008, 5127],
#  [5243, 1718, 1445, 959],
#  [1445,
#   1718,
#   4852,
#   1524,
#   7385,
#   1445,
#   1718,
#   3173,
#   6647,
#   6507,
#   4153,
#   1524,
#   7385],
#  [1742, 3818, 5818, 7268, 7141, 743],
#  [3008, 6521, 3008, 6294, 6647, 6507, 2789, 7150, 7385, 6146],
#  [3284, 2897, 7106, 4619],
#  [3008, 2056, 1362, 2581],
#  [6647, 1869, 2282, 232, 6442, 6395, 88, 1399, 1432, 5559],
#  [6647, 6507, 4153, 6442, 6691, 88, 5557, 7385, 7385],
#  [3008, 4472, 5818, 5072, 6478, 14, 5981],
#  [6647, 6507, 5882],
#  [6442, 3437, 1718, 4525, 5818, 14, 3035],
#  [3008,
#   5072,
#   6478,
#   14,
#   1931,
#   1352,
#   7385,
#   1399,
#   6507,
#   3422,
#   2717,
#   6389,
#   7224,
#   5818,
#   7356,
#   360,
#   3008,
#   6647,
#   6507,
#   1066,
#   2084],
#  [4264,
#   2899,
#   5243,
#   3290,
#   88,
#   6442,
#   2464,
#   4254,
#   5613,
#   6442,
#   7191,
#   1718,
#   4154,
#   7385,
#   3008,
#   14,
#   5981],
#  [753, 5175, 5818, 4561, 1869, 2236, 1047, 2282, 3008],
#  [3008, 2236, 1821, 3008, 1821, 4577, 6442, 3256, 1685, 1434, 88, 5343, 3342],
#  [3008, 4287],
#  [7385, 7385, 4577, 6647, 3818, 5072, 138, 1718, 1997, 2939, 4472, 5416, 5981],
#  [3008, 5787, 5981, 2282, 4505],
#  [1718, 5981, 6442, 743, 5818, 4711, 7385, 7385],
#  [3008, 1577, 6389, 336, 7385, 1929, 4659, 3101, 2236, 1362, 4272],
#  [4495, 5557, 7385],
#  [3951,
#   2481,
#   2994,
#   2004,
#   5557,
#   580,
#   88,
#   1503,
#   4264,
#   1839,
#   1205,
#   2004,
#   6952,
#   487,
#   6442,
#   6212,
#   4686,
#   1246,
#   2215,
#   932,
#   5913],
#  [1205, 4525, 1718, 6091, 1445, 7242, 6442, 7385, 88, 1, 3781, 88, 6442, 7385],
#  [2899, 5243, 5072, 3008, 6455, 336, 7385],
#  [1445, 2056, 1362, 239],
#  [5818, 14, 5818, 4561, 6478, 705, 1929, 7385],
#  [2899, 2025],
#  [6507, 3008, 3422, 7155, 5818, 7356, 7385, 5818, 7356, 7237],
#  [5818, 7356, 6478, 932, 6049, 5925, 5818, 3234, 6442, 727],
#  [2326, 6952, 6952, 4485],
#  [7385,
#   667,
#   3035,
#   1036,
#   2572,
#   2004,
#   905,
#   3821,
#   2218,
#   5243,
#   5072,
#   3008,
#   7117,
#   5243,
#   6507,
#   3008,
#   6016,
#   1685],
#  [5072, 6478, 134, 1931],
#  [1742, 6507, 6647, 1292],
#  [5818, 7356, 5853, 2004, 3008],
#  [4619, 4619, 4899, 2004, 905],
#  [5818,
#   1872,
#   3008,
#   7059,
#   6879,
#   987,
#   3620,
#   4945,
#   1490,
#   3141,
#   6193,
#   3313,
#   431,
#   2282,
#   6819,
#   3008,
#   4520,
#   4705,
#   5320,
#   5557,
#   5429,
#   4705,
#   431,
#   5557,
#   5429],
#  [3008, 2261, 6442, 4107],
#  [820, 4264, 4125],
#  [5818, 545, 4577, 88, 1399],
#  [6367,
#   3008,
#   6119,
#   1076,
#   6442,
#   7385,
#   88,
#   3035,
#   5925,
#   4416,
#   6952,
#   6987,
#   5416,
#   5981],
#  [5243, 5416, 7385],
#  [4238, 4442, 6507, 6016, 6543, 2248, 1445, 648, 2084, 2282, 7385],
#  [6952, 1445, 1718, 6375, 4485],
#  [5072, 6478, 4441, 5416, 4717, 4472, 5416, 354],
#  [5243, 5416, 3422, 4816, 6030, 31, 6030],
#  [3161, 5818, 3949, 3620, 7385, 4153, 5981, 6376, 88, 103],
#  [5243, 1718, 932, 2607, 5477, 894],
#  [5818, 3366, 7385, 3290, 1718, 2286],
#  [6952, 6952, 2789],
#  [1205, 987],
#  [7385,
#   6952,
#   2868,
#   2461,
#   5818,
#   6602,
#   4705,
#   6049,
#   7141,
#   1718,
#   6442,
#   7136,
#   2459,
#   88,
#   932,
#   1267,
#   5072,
#   6478,
#   6618,
#   2282,
#   6143,
#   6218,
#   6738,
#   134,
#   4619,
#   2461,
#   6952],
#  [7141, 1718, 6478, 5416, 727, 7385, 5818, 7117, 932, 5213, 2663, 905],
#  [5243, 7321, 5072, 3008, 7117],
#  [5818,
#   7117,
#   2282,
#   14,
#   5416,
#   932,
#   7307,
#   5818,
#   7117,
#   2282,
#   14,
#   5416,
#   932,
#   7385,
#   2025,
#   3008,
#   6507,
#   6375],
#  [5787,
#   905,
#   5416,
#   354,
#   5243,
#   3008,
#   1821,
#   2389,
#   5557,
#   3711,
#   1025,
#   5243,
#   932,
#   1459,
#   1577,
#   2366],
#  [3422, 1096, 6219, 7385, 905, 598, 3422, 7385, 4264, 3422, 1570, 545, 1277],
#  [932, 1570, 545, 1277],
#  [267,
#   6099,
#   648,
#   1277,
#   4083,
#   3520,
#   2282,
#   905,
#   6099,
#   648,
#   2282,
#   645,
#   7313,
#   3872,
#   5775,
#   2282,
#   7385,
#   905],
#  [2084, 2663, 6442, 4147, 7385],
#  [267,
#   7385,
#   5775,
#   6449,
#   2593,
#   2582,
#   4245,
#   4555,
#   5722,
#   2593,
#   1997,
#   1277,
#   4264,
#   3422,
#   1096,
#   4654,
#   905,
#   1685,
#   2593,
#   7385],
#  [932, 1096, 4654, 3008, 1685, 932, 6896, 7385],
#  [5981, 1718, 5243, 1445, 1821, 2282, 905, 1445, 1960, 4107, 3909, 4153, 905],
#  [932, 1096, 1960, 4107, 3909, 4153, 3008],
#  [3909, 4153, 3422, 2084, 5383, 5818, 545, 5557, 316, 1025],
#  [5818, 7356, 7385, 5072, 6478, 3008, 4472],
#  [7224,
#   6647,
#   6422,
#   4456,
#   588,
#   4264,
#   2,
#   6647,
#   6507,
#   151,
#   6647,
#   6507,
#   5320,
#   2282,
#   2470,
#   1910],
#  [3422,
#   5216,
#   4220,
#   4264,
#   5818,
#   7372,
#   5557,
#   4789,
#   5818,
#   1085,
#   7002,
#   3313,
#   6010,
#   4264,
#   5557,
#   743,
#   545,
#   7385,
#   2593,
#   1929,
#   74,
#   545,
#   4153,
#   6442,
#   4755,
#   1445,
#   1085,
#   2917,
#   905,
#   4264,
#   5818,
#   5023,
#   4717],
#  [2055, 5981, 1718, 5557, 7385, 4478],
#  [138, 5818, 1291, 1308, 88, 3799, 1192],
#  [2,
#   3008,
#   1507,
#   2004,
#   6442,
#   4387,
#   2248,
#   4442,
#   6056,
#   3061,
#   3008,
#   2004,
#   932,
#   3662],
#  [5818, 6056, 2, 4442, 5072, 6478, 6843, 905, 2084],
#  [6507, 3008, 3674],
#  [2351],
#  [5818, 4043, 667, 3008, 2282, 3422, 3667],
#  [6442, 1432, 6507, 3909, 88, 2835, 4839, 4193, 3909, 6568],
#  [7385, 4200, 1718, 5860],
#  [3008, 4197, 7170, 5557, 1834],
#  [4619, 5818, 4197, 3035],
#  [1821, 3008, 6676, 6956, 5896, 6588],
#  [6952],
#  [5243, 5416, 2084, 7002],
#  [5818,
#   1085,
#   6375,
#   5818,
#   503,
#   6952,
#   727,
#   5818,
#   4711,
#   6952,
#   3313,
#   5818,
#   3153,
#   5162,
#   5557,
#   5391,
#   651,
#   3008,
#   1869,
#   2282,
#   1869,
#   5557,
#   2451,
#   4838,
#   2282,
#   5162,
#   5963,
#   4442,
#   7385,
#   905,
#   5818,
#   3101,
#   1869,
#   5722,
#   5557,
#   1337,
#   88,
#   727,
#   5818,
#   4197,
#   3035,
#   1205,
#   987,
#   6478,
#   712,
#   5818,
#   7356,
#   4442,
#   2422,
#   905,
#   6630,
#   6442,
#   3018,
#   2917,
#   7385],
#  [7224, 3008, 1577, 2236, 5557, 1834],
#  [5243, 6507, 3008, 7152, 905],
#  [5818, 7356, 6478, 5557, 5959, 5818, 7356, 6478, 5557, 5959],
#  [5818, 14],
#  [3008,
#   5072,
#   6478,
#   14,
#   5818,
#   7356,
#   1615,
#   5818,
#   545,
#   7153,
#   5981,
#   1718,
#   6478,
#   905,
#   5818,
#   5023,
#   5557,
#   6412,
#   3818,
#   3008,
#   7220,
#   5243,
#   4442,
#   6056,
#   5072,
#   2282,
#   905,
#   5383,
#   5818,
#   2564,
#   2282,
#   4565],
#  [4442, 6507, 6478, 7175, 6843, 3008, 6389, 2084],
#  [6507, 3008, 2055],
#  [5818, 2696, 4043, 1699, 7385, 5613],
#  [1718, 1445, 932, 5504],
#  [7385, 1445, 1718, 5920, 6507, 3008, 2639],
#  [2, 5818, 545, 932, 5504, 5818, 739, 1362],
#  [5557, 3706, 7385, 6049, 3101, 120, 6442, 3810, 3109, 3658, 3313],
#  [6952, 43, 5243, 7385, 7356, 3013, 5818, 5242, 3008],
#  [3008, 6260, 5162, 5712],
#  [5072, 3008, 1869, 2161],
#  [2663, 6442, 1173],
#  [5818, 6056, 5224, 7059, 1685, 5343],
#  [5243, 6507, 3008, 959],
#  [4704, 5416, 905, 3008, 1869, 5318, 1946, 88, 932, 4052],
#  [5072, 3008, 3620, 297, 905, 2282, 4704, 5416, 3008],
#  [5818, 5072, 6478, 297, 2282, 1422, 3008, 2218, 2004, 905],
#  [5818, 473, 932, 1951, 5818, 4043, 3061, 5818, 6119, 3234, 1931],
#  [1169, 4766, 2917, 6442, 1538, 3008, 14, 1399, 4696],
#  [7385,
#   545,
#   5557,
#   4179,
#   88,
#   3828,
#   3422,
#   2454,
#   545,
#   5517,
#   6099,
#   2915,
#   905,
#   321,
#   2690],
#  [5278,
#   3008,
#   5787,
#   5343,
#   2461,
#   6478,
#   6647,
#   6056,
#   3181,
#   3909,
#   6260,
#   2,
#   3035,
#   5758,
#   5325,
#   3008],
#  [2, 5818, 5787, 3008, 6056, 3008, 2370, 905],
#  [6507,
#   3008,
#   6375,
#   7385,
#   5072,
#   6478,
#   4441,
#   5416,
#   5981,
#   6647,
#   6056,
#   325,
#   2282,
#   7385,
#   4442,
#   6056,
#   6478,
#   7385,
#   3008],
#  [5557, 6412],
#  [5818,
#   7356,
#   5325,
#   5557,
#   316,
#   1784,
#   2663,
#   7385,
#   2366,
#   6442,
#   6488,
#   6375,
#   6442,
#   3799,
#   1718,
#   6389,
#   5557,
#   7238,
#   1718,
#   146,
#   7224,
#   5818,
#   7385],
#  [3161,
#   6647,
#   3818,
#   3061,
#   3008,
#   1205,
#   6389,
#   138,
#   6647,
#   1869,
#   2282,
#   4714,
#   2004,
#   5243,
#   1718,
#   2956,
#   6375,
#   5787,
#   5343,
#   6442,
#   7385,
#   5981,
#   6442,
#   6307],
#  [2326],
#  [3035, 545, 3422, 6920, 6478, 1929],
#  [6367,
#   5818,
#   7356,
#   6442,
#   4815,
#   85,
#   5082,
#   2760,
#   4264,
#   3951,
#   138,
#   4264,
#   2899,
#   5818,
#   3366,
#   2366,
#   2282,
#   1362,
#   115,
#   2663,
#   6480],
#  [3161,
#   2421,
#   7385,
#   7385,
#   905,
#   3008,
#   3818,
#   5072,
#   6442,
#   6434,
#   1159,
#   5477,
#   5416,
#   5981,
#   6442,
#   2459,
#   1718,
#   4577,
#   1045],
#  [2326, 267, 2055],
#  [5818, 7356, 537, 2282, 1362, 7385, 3990, 5343],
#  [712, 1821, 243, 4264, 7385],
#  [712, 5072, 3008, 4472, 85],
#  [2899, 2025, 6119, 3008, 325, 2282, 6442, 4906],
#  [2659, 85, 5243, 6507, 3008, 959, 6375],
#  [1961,
#   6708,
#   545,
#   4153,
#   6442,
#   3249,
#   1685,
#   311,
#   6647,
#   1218,
#   4525,
#   7224,
#   6099,
#   3101,
#   5162,
#   3245,
#   1721],
#  [5243, 5072, 3008, 4328, 7385, 7385],
#  [5818, 2915, 2593, 667, 5557, 2454],
#  [5557, 2454, 1821, 3008, 667, 3313, 212],
#  [6952, 3088, 6396],
#  [85, 2435, 2, 5818, 667, 2593],
#  [6442,
#   2788,
#   3908,
#   1869,
#   7360,
#   5478,
#   5243,
#   6647,
#   5072,
#   4264,
#   138,
#   3008,
#   6507,
#   1292,
#   2282,
#   185,
#   6223,
#   2408,
#   7141,
#   1718,
#   1292,
#   2282,
#   1362,
#   6223,
#   7385,
#   1724],
#  [5243,
#   545,
#   5818,
#   2155,
#   2282,
#   5072,
#   6442,
#   3848,
#   4836,
#   2282,
#   6868,
#   905,
#   5818,
#   545,
#   7175,
#   6843,
#   5557,
#   6412,
#   2084,
#   5818,
#   3565,
#   5263],
#  [5263, 3008, 7385, 5557, 7238, 2282, 5557, 4626],
#  [85, 5818, 14, 5818, 2120, 1721, 1205, 7141, 3848, 545, 6952, 4034, 7238],
#  [6367, 7141, 1718, 7175, 191, 932, 810, 4264, 2943, 3828],
#  [191, 3422, 810],
#  [5477,
#   6507,
#   3008,
#   1292,
#   2282,
#   1659,
#   7141,
#   2248,
#   2,
#   7385,
#   1895,
#   7208,
#   1442,
#   4264,
#   3008,
#   3366,
#   3027,
#   4153,
#   6442,
#   7322,
#   389,
#   2389,
#   5557,
#   4882,
#   7141,
#   103,
#   3366,
#   1362,
#   1183,
#   2282,
#   1659,
#   3008,
#   3366,
#   1869,
#   6442,
#   3706,
#   2282,
#   3823,
#   5632,
#   6442,
#   2582,
#   987,
#   1494,
#   5981,
#   5818,
#   1869,
#   2282,
#   5224,
#   6480,
#   4974,
#   5046,
#   932,
#   6434,
#   7385,
#   1205,
#   4929,
#   3088,
#   5818,
#   3818,
#   5072,
#   5296,
#   932,
#   3935],
#  [1205, 85, 147, 7141],
#  [5072,
#   6478,
#   3008,
#   7053,
#   7118,
#   987,
#   4577,
#   5416,
#   2408,
#   6442,
#   6260,
#   6647,
#   3161,
#   6442,
#   2868,
#   727,
#   5818,
#   5162,
#   2282,
#   2422,
#   3008,
#   7053,
#   6614],
#  [267, 6389],
#  [5243, 545, 5981, 7385],
#  [5818,
#   2618,
#   267,
#   3008,
#   6507,
#   6389,
#   85,
#   2389,
#   5086,
#   2389,
#   6647,
#   5162,
#   4100,
#   6647,
#   6056,
#   2915,
#   3008,
#   4529,
#   6442,
#   2754],
#  [1821, 6442, 4387, 7385, 2593, 5935],
#  [267, 1445, 2886, 6416, 7106],
#  [2055,
#   3354,
#   4585,
#   2593,
#   1294,
#   2915,
#   2593,
#   2708,
#   1721,
#   2593,
#   4520,
#   4264,
#   667,
#   2593,
#   4265,
#   2282,
#   3383,
#   6688,
#   3008,
#   2564,
#   5981],
#  [2161, 1685, 905, 5818, 5843, 6284, 2218],
#  [7326, 7385],
# ...
#  [5628, 5818, 1334, 2903, 3035],
#  [6367, 3565, 7224, 3008, 14, 5818, 6449, 3008, 7053, 6442, 2085],
#  [6367, 3565, 7224, 3008, 14, 5818, 5072, 6478, 315, 5416, 5981, 6266],
#  [5628, 2025, 4561, 3008],
#  [5818, 5072, 6478, 3063, 4593, 6413],
#  [1821, 3008, 5162, 5557, 1115, 5325, 6442, 905],
#  [2235,
#   1205,
#   5818,
#   3366,
#   2366,
#   2282,
#   349,
#   3008,
#   6242,
#   3008,
#   2564,
#   5557,
#   5575,
#   2004,
#   905],
#  [2,
#   3008,
#   1081,
#   905,
#   7385,
#   4153,
#   932,
#   5606,
#   4976,
#   3035,
#   739,
#   1901,
#   3008,
#   3311,
#   212,
#   5243,
#   5416,
#   6442,
#   1115],
#  [6442,
#   1533,
#   2618,
#   1445,
#   3366,
#   1026,
#   2593,
#   6588,
#   1205,
#   6099,
#   6119,
#   6993,
#   6375],
#  [3012],
#  [7385],
#  [2248,
#   3008,
#   5072,
#   6478,
#   315,
#   5416,
#   5981,
#   6533,
#   7385,
#   4482,
#   5818,
#   1869,
#   503,
#   2663,
#   6416],
#  [5243, 3366, 3008, 6602, 2593],
#  [2248,
#   987,
#   5557,
#   2985,
#   103,
#   2461,
#   4456,
#   2662,
#   2282,
#   6843,
#   5557,
#   4378,
#   4799,
#   7385,
#   6507,
#   5863,
#   6784,
#   5464,
#   2663,
#   5460,
#   4785,
#   3035,
#   3101,
#   1362,
#   2282,
#   7385,
#   4505,
#   3565,
#   5881,
#   4505,
#   1721,
#   6952,
#   1284,
#   4847,
#   987,
#   2366,
#   7385,
#   4505,
#   2282,
#   3932],
#  [5460, 4785, 2366, 5243, 7385, 7385],
#  [5818, 6056, 4899, 2004, 3008],
#  [4525, 4463, 5557, 5082, 4525, 6056, 1362, 3088, 1685, 3008, 2282, 5072],
#  [5818, 3818, 4593, 3008, 3109, 2248, 5818, 6056, 1497, 6242],
#  [7141, 1496, 4478, 7042],
#  [3422,
#   1459,
#   6507,
#   5325,
#   7385,
#   5818,
#   3818,
#   3061,
#   2004,
#   6442,
#   5460,
#   2924,
#   1656],
#  [3008, 6507, 5994],
#  [3422, 5685, 6507],
#  [3008, 1292, 2282, 6442, 904, 7036],
#  [3008, 2564, 7360, 6260, 6000],
#  [2435, 2, 5818, 7133, 4979, 2004, 3008],
#  [7141, 4254, 3088, 2282, 5072, 2004, 932, 5082],
#  [5818, 6056, 2915, 3008, 14, 5243, 3772],
#  [7141,
#   1718,
#   1586,
#   5818,
#   7356,
#   6478,
#   7175,
#   1362,
#   2663,
#   932,
#   2789,
#   6647,
#   3818,
#   325,
#   6442,
#   2459,
#   147],
#  [5787,
#   3008,
#   5243,
#   5818,
#   6056,
#   7108,
#   3008,
#   5557,
#   1874,
#   2,
#   3008,
#   2458,
#   3008,
#   3818,
#   4899,
#   2004,
#   905,
#   2,
#   3008,
#   5072,
#   6478,
#   2458,
#   3008,
#   5072,
#   6478,
#   4899],
#  [2625, 4921],
#  [4860, 7268, 5343, 2917, 7385, 4264, 6721, 2353, 5585, 7385],
#  [3008, 6289],
#  [5818, 7356, 4153, 7197],
#  [7224,
#   7356,
#   5818,
#   2055,
#   5818,
#   6056,
#   1997,
#   4790,
#   4264,
#   3008,
#   5159,
#   6442,
#   2084],
#  [88, 3052],
#  [2659,
#   5818,
#   6219,
#   4469,
#   2282,
#   1362,
#   5557,
#   6412,
#   5383,
#   5818,
#   545,
#   5557,
#   2383,
#   5818,
#   4173,
#   88,
#   6975,
#   1721,
#   2282,
#   5557,
#   6400,
#   1231,
#   3035,
#   2663,
#   2833,
#   3422,
#   74,
#   4264,
#   3725,
#   7385,
#   2917,
#   6442,
#   2582,
#   3848,
#   5243,
#   3366,
#   3008,
#   5975,
#   5416],
#  [5818,
#   4469,
#   2282,
#   831,
#   1721,
#   2282,
#   5557,
#   5796,
#   4153,
#   5082,
#   5699,
#   2663,
#   6442,
#   6400,
#   877,
#   4495,
#   6442,
#   7286,
#   4264,
#   30,
#   5557,
#   2383],
#  [5243, 6507, 3008, 6764, 2025, 6507, 3008, 2522],
#  [6099, 3565, 1820, 2625, 88, 2593, 4700, 598, 4442, 2943, 2486, 2593],
#  [2025, 6478],
#  [6099, 1718, 2813, 3063, 2, 5981, 7310, 1718, 4237],
#  [3161,
#   2915,
#   905,
#   325,
#   2282,
#   2593,
#   7360,
#   5944,
#   5818,
#   5162,
#   4442,
#   6507,
#   4577,
#   1045,
#   3565,
#   2915,
#   905,
#   1869,
#   5557,
#   105,
#   3703,
#   2917,
#   2593],
#  [3008, 1981, 325, 2282, 2593, 5266],
#  [267],
#  [5243, 3366, 932, 3535, 4472, 88, 5981],
#  [5818, 5072, 6478, 1869, 5557, 3535],
#  [3422, 630, 2514],
#  [5818, 7356, 1714, 6375],
#  [7224, 7356, 5818],
#  [1169, 3008, 7385, 2593, 6414, 3008, 6507, 5557, 4576, 6099, 2834, 905, 6700],
#  [3008,
#   6507,
#   2593,
#   7385,
#   1718,
#   6099,
#   6442,
#   2383,
#   3008,
#   6507,
#   7175,
#   30,
#   5325,
#   6442,
#   5881,
#   5796],
#  [5078,
#   5787,
#   3008,
#   5243,
#   5818,
#   6056,
#   6172,
#   3008,
#   5557,
#   7179,
#   4766,
#   3008,
#   667,
#   2593,
#   2282,
#   6442,
#   4200,
#   3790,
#   5072,
#   6478,
#   2915,
#   2593,
#   3909,
#   88,
#   932,
#   2182,
#   6099,
#   1718,
#   6442,
#   4688,
#   1162,
#   7203,
#   6647,
#   2564,
#   4602],
#  [2659, 5818, 7356, 5557, 1364],
#  [3161, 3109, 5818, 7356, 4702, 3008, 5818, 6119, 2437, 2593],
#  [6367, 3008, 7303, 651, 7352, 7175, 1699, 3008, 7385, 905],
#  [5818, 6353, 2593, 4525, 1685, 5557, 2454, 4264, 5981, 1718, 3035],
#  [267,
#   3565,
#   2593,
#   2663,
#   6442,
#   2454,
#   3088,
#   6396,
#   3161,
#   5818,
#   7356,
#   2235,
#   3008,
#   2943,
#   4472,
#   5818,
#   7356,
#   5557,
#   5534,
#   4264,
#   5818,
#   2813,
#   1721,
#   1205],
#  [6952,
#   5818,
#   5072,
#   6478,
#   4472,
#   3008,
#   1577,
#   5557,
#   5534,
#   5818,
#   3565,
#   4472,
#   3008,
#   1577,
#   6635,
#   5416,
#   3035,
#   5818,
#   4328,
#   2282,
#   134,
#   6442,
#   1920,
#   3008,
#   3417,
#   14,
#   6260,
#   3008,
#   5072,
#   6478,
#   14,
#   2593,
#   6367,
#   5318,
#   6099,
#   1718,
#   2564,
#   6442,
#   3229,
#   2282,
#   645,
#   2603,
#   3008,
#   3063,
#   2,
#   6099,
#   7385,
#   5981,
#   3008,
#   5722,
#   5557,
#   5256,
#   2917,
#   2593,
#   987,
#   2570,
#   147,
#   3008,
#   3818,
#   3595,
#   3035,
#   4577,
#   3008,
#   297,
#   1205,
#   3035,
#   6056,
#   6478,
#   5224,
#   3313,
#   645,
#   4221,
#   88,
#   4447,
#   3008,
#   6507,
#   7188],
#  [5818,
#   473,
#   3008,
#   3008,
#   14,
#   5818,
#   6274,
#   5818,
#   545,
#   959,
#   6442,
#   6389,
#   103,
#   3008,
#   14,
#   5818,
#   4472,
#   6099,
#   1718,
#   4034],
#  [6367,
#   987,
#   6478,
#   1721,
#   2282,
#   3008,
#   2282,
#   3045,
#   5278,
#   6099,
#   1718,
#   4034,
#   2461,
#   6478,
#   5072,
#   6478,
#   3008,
#   7118,
#   5981,
#   1718,
#   2025,
#   3008,
#   6507,
#   5557,
#   1364],
#  [1205,
#   5818,
#   4328,
#   6119,
#   3008,
#   6676,
#   1997,
#   3909,
#   4153,
#   5557,
#   659,
#   1685,
#   5289,
#   5818,
#   4328,
#   3008,
#   7303,
#   33,
#   2593,
#   4525,
#   4702,
#   2593,
#   4249,
#   7385,
#   2878,
#   2593],
#  [2025,
#   3366,
#   3008,
#   3061,
#   905,
#   2084,
#   4525,
#   2004,
#   6442,
#   85,
#   2025,
#   3366,
#   3008,
#   1446,
#   1721,
#   1685,
#   905,
#   2366,
#   5981],
#  [7385, 3121],
#  [5243, 5072, 3008, 297],
#  [932,
#   2941,
#   3008,
#   3234,
#   4442,
#   1292,
#   2282,
#   5224,
#   5557,
#   4816,
#   5416,
#   905,
#   212,
#   3109,
#   4264,
#   1312,
#   4671],
#  [5243, 1718, 932, 7385],
#  [5818, 6422, 4456, 588],
#  [2899, 5072, 3035, 2232],
#  [7224,
#   7385,
#   5072,
#   6478,
#   1869,
#   2282,
#   5072,
#   7206,
#   7385,
#   4442,
#   1292,
#   2282,
#   1869,
#   4492,
#   4816,
#   7141,
#   4502],
#  [3008,
#   3620,
#   4472,
#   3008,
#   6056,
#   1362,
#   2020,
#   2282,
#   5534,
#   5557,
#   4631,
#   2004,
#   7141,
#   5954,
#   5477,
#   2570,
#   6635,
#   6507,
#   3008],
#  [18, 5437, 3035, 3161, 2366, 5557, 2360],
#  [6647,
#   5072,
#   6478,
#   14,
#   5981,
#   1157,
#   987,
#   894,
#   212,
#   6984,
#   4929,
#   5557,
#   1337,
#   2282,
#   1362,
#   1122],
#  [5477, 2776, 1211, 6507, 1721, 4525],
#  [4525, 6507, 2625, 4842, 1081, 2917, 7141, 630],
#  [3818, 6647, 1997, 1721, 2282, 6442, 5606, 4976],
#  [3008, 14, 3008, 4043, 5072, 5981, 1169],
#  [1718, 3035, 3067, 3176],
#  [18, 3818, 3008, 5787, 5343, 5243, 6396, 6375],
#  [5818,
#   7118,
#   1205,
#   5818,
#   4479,
#   5981,
#   6442,
#   5082,
#   2760,
#   1718,
#   6375,
#   2004,
#   3008,
#   1718,
#   7141,
#   964,
#   3176,
#   2282,
#   6442,
#   5082,
#   1192],
#  [5818, 3620, 4043, 6172, 3909, 7360, 7222, 6389, 138, 2917, 7141, 630],
#  [5078,
#   1205,
#   5818,
#   5072,
#   7118,
#   5981,
#   932,
#   1951,
#   4860,
#   7385,
#   3027,
#   2661,
#   1718,
#   5981,
#   2860],
#  [1445, 545, 2912, 1205, 6478, 5464, 1445, 6056, 1362, 3582],
#  [5072, 3008, 1869, 6442, 4482, 2663, 1308],
#  [7385,
#   1718,
#   6478,
#   5557,
#   3706,
#   4502,
#   5078,
#   18,
#   7385,
#   2912,
#   1445,
#   1718,
#   3582,
#   5818,
#   1869,
#   2564,
#   5557,
#   5082,
#   2760,
#   5023,
#   18,
#   330,
#   1718,
#   2912,
#   1205,
#   6478,
#   5464],
#  [3109, 6507, 3008, 5078],
#  [267, 6362, 6478, 5557, 3706, 4502],
#  [2055],
#  [2055],
#  [2055],
#  [2055],
#  [2659, 5591],
#  [5243,
#   1718,
#   932,
#   5575,
#   2025,
#   3366,
#   3008,
#   4795,
#   2917,
#   905,
#   5818,
#   3565,
#   4469,
#   5557,
#   568],
#  [5818, 7385, 4043, 500, 3008, 3565, 651, 3008, 297, 905, 2282, 500, 3008],
#  [3008,
#   6119,
#   1869,
#   2282,
#   1289,
#   905,
#   2663,
#   7322,
#   88,
#   3422,
#   2999,
#   3008,
#   3101,
#   6172,
#   905,
#   6242],
#  [2326, 5818, 7356, 1615, 1821, 5818, 1289, 3008, 6259, 2326],
#  [1679, 3035],
#  [2248,
#   5818,
#   4561,
#   3565,
#   3274,
#   7385,
#   2282,
#   6442,
#   1020,
#   4264,
#   134,
#   5072,
#   3008,
#   2435,
#   2,
#   6647,
#   3565,
#   5963,
#   6242,
#   3909],
#  [2055, 2055, 3109, 5072, 6478, 7385, 905],
#  [5818, 7356, 6478],
#  [4619,
#   3008,
#   6507,
#   5818,
#   7356,
#   6478,
#   3565,
#   7059,
#   4906,
#   5818,
#   5072,
#   6478,
#   3565,
#   4240,
#   5557,
#   7385,
#   2663,
#   932,
#   4499,
#   3008,
#   3101,
#   6172,
#   905,
#   6242],
#  [267,
#   6367,
#   3008,
#   6353,
#   6442,
#   1687,
#   4264,
#   1960,
#   3035,
#   6389,
#   2218,
#   4153,
#   6442,
#   5528,
#   5981,
#   545],
#  [5981, 545, 3706, 3008, 1577, 1202, 6442, 5528],
#  [3008,
#   1577,
#   7385,
#   3008,
#   6119,
#   6172,
#   5557,
#   4485,
#   2,
#   3008,
#   2564,
#   905,
#   2461,
#   6478],
#  [6367, 712, 545, 3035, 5981, 6921, 905, 5477, 2282, 5072, 5981, 6972],
#  [3008, 6507, 7385],
#  [3161, 2917, 7141, 3008, 1869, 5357, 4153, 932, 4586, 7147, 1718, 3035],
#  [3101, 1362, 7385],
#  [5072, 6478, 4441, 5416, 6442, 3722, 2158, 5818, 6056, 6478, 500, 3035],
#  [500, 6442, 2158],
#  [6952, 5787, 905, 5243, 3008, 297, 2282, 134],
#  [500, 3035],
#  [2326,
#   3422,
#   7385,
#   4442,
#   297,
#   905,
#   2282,
#   6050,
#   4442,
#   297,
#   905,
#   2282,
#   6050,
#   6986],
#  [5981, 1718, 3706],
#  [267],
#  [6367, 5981, 1718, 4121],
#  [5078,
#   5981,
#   1718,
#   4121,
#   1205,
#   5818,
#   4043,
#   1997,
#   138,
#   6647,
#   6507,
#   2663,
#   6442,
#   5625,
#   88,
#   6242,
#   6375],
#  [6952, 1997, 1974, 3008, 6507, 7175, 1362, 4121],
#  [6952,
#   6952,
#   1352,
#   2282,
#   905,
#   6375,
#   5818,
#   297,
#   2282,
#   14,
#   5243,
#   3008,
#   6507,
#   3256,
#   5416,
#   3008,
#   14,
#   6442,
#   3985,
#   103,
#   4264,
#   6442,
#   7385,
#   4264],
#  [5818,
#   6056,
#   5787,
#   3008,
#   6986,
#   5168,
#   5072,
#   3035,
#   6986,
#   2389,
#   5086,
#   2389,
#   3008,
#   5162,
#   2084,
#   6647,
#   6056,
#   325,
#   6647,
#   6056,
#   325],
#  [3089],
#  [5818,
#   3089,
#   6647,
#   6056,
#   325,
#   3008,
#   6056,
#   1362,
#   4121,
#   3008,
#   6056,
#   1362,
#   3582,
#   1997,
#   1974,
#   3565,
#   7220,
#   5981,
#   6936,
#   3565,
#   3161,
#   4495,
#   6442,
#   7385,
#   4264,
#   7220,
#   3008,
#   6507,
#   3256,
#   2282,
#   905],
#  [267, 5818, 6056, 5072, 5981, 2389, 772, 2389, 3008, 6507, 6478, 7385, 905],
#  [7385, 3008, 6417, 5818, 1644, 3008],
#  [5078, 4655, 6986],
#  [6986],
#  [3008, 3089],
#  [267, 5818, 3089],
#  [5078,
#   4264,
#   3008,
#   14,
#   5243,
#   5818,
#   6056,
#   3354,
#   4585,
#   3422,
#   3667,
#   3207,
#   5557,
#   2764,
#   7385,
#   88,
#   893,
#   4264,
#   2248,
#   3565,
#   6064,
#   4505,
#   3909,
#   3296,
#   2282,
#   7385,
#   5981,
#   3366,
#   5981,
#   1362,
#   5557,
#   3706,
#   103],
#  [267, 267, 3706, 103],
#  [5078],
#  [3234, 3008, 5355, 3706, 6365],
#  [77, 3008],
#  [7224,
#   6647,
#   6507,
#   3905,
#   2282,
#   2460,
#   7141,
#   143,
#   6647,
#   2564,
#   312,
#   7036,
#   2004,
#   6442,
#   1829,
#   6154,
#   7385,
#   4585,
#   537,
#   2282,
#   1997,
#   5818,
#   134,
#   770,
#   5162,
#   5557,
#   5400,
#   3417,
#   6442,
#   3126,
#   5818,
#   1997,
#   2282,
#   5162,
#   6442,
#   5400,
#   4264,
#   1034,
#   4577,
#   6442,
#   3270,
#   5818,
#   6956,
#   373,
#   4264,
#   5557,
#   2383,
#   2004,
#   5557,
#   2854,
#   2915,
#   3313,
#   1997,
#   6389,
#   1742,
#   5818,
#   545,
#   7385,
#   5981,
#   4363,
#   3027,
#   3035,
#   5818,
#   4363,
#   503,
#   3422,
#   7179,
#   7377,
#   3311,
#   4264,
#   1685,
#   5243,
#   7059,
#   6635,
#   2383,
#   2564,
#   7385,
#   4967,
#   6442,
#   928,
#   3311,
#   4264,
#   987,
#   147,
#   2,
#   5818,
#   1895,
#   5613,
#   2084,
#   1685,
#   5981,
#   5400,
#   1685,
#   5557,
#   2582,
#   5120,
#   5818,
#   3366,
#   1869,
#   503,
#   3422,
#   7179,
#   7377,
#   3311],
#  [7256, 2461, 5355, 5981, 1718, 2102],
#  [6478,
#   7380,
#   1721,
#   6478,
#   7380,
#   1721,
#   2366,
#   5981,
#   5818,
#   4328,
#   5243,
#   5072,
#   5818,
#   2564,
#   4602,
#   4548,
#   4122,
#   5557,
#   157,
#   2461,
#   2625,
#   7385,
#   6375,
#   4264,
#   4525,
#   4264,
#   2663,
#   5557,
#   4548,
#   5502,
#   6952,
#   3313,
#   4871,
#   905,
#   5170],
#  [5818, 4472, 3008, 6507, 7290, 5557, 5216, 7385, 4525, 3109],
#  [5477, 3509, 6507, 932, 3152],
#  [7224, 5243, 1718, 2487],
#  [1445,
#   1718,
#   5325,
#   7385,
#   1929,
#   3535,
#   545,
#   1990,
#   212,
#   772,
#   2282,
#   1960,
#   2593,
#   1426,
#   4153,
#   4442,
#   1577,
#   6214,
#   1685,
#   5557,
#   4749,
#   5081,
#   2593,
#   2004,
#   5557,
#   5825,
#   1888],
#  [5981, 1718, 2487],
#  [5818,
#   4914,
#   7141,
#   1646,
#   3908,
#   831,
#   3422,
#   4908,
#   6507,
#   6394,
#   905,
#   2572,
#   4603,
#   905],
#  [537],
#  [232, 4505, 3909, 88, 3422, 2789],
#  [5078, 3008, 537],
#  [7360, 1573, 6647, 3818, 5072, 5981, 6974],
#  [5078,
#   3008,
#   5963,
#   2663,
#   5557,
#   7326,
#   7245,
#   5818,
#   7118,
#   5981,
#   4264,
#   5243,
#   6376,
#   88,
#   5963,
#   5072,
#   3008,
#   5072],
#  [5818, 7356, 4001],
#  [3008, 6507, 5557, 4001, 5243, 5072, 3008, 321, 4399, 7385, 1685],
#  [3008, 6266, 7385, 2663, 3035],
#  [4264, 5243, 5072, 3008, 5072, 2004, 6442, 4732],
#  [6507, 3008, 3674],
#  [4899,
#   2282,
#   4522,
#   7385,
#   5072,
#   6478,
#   2261,
#   6442,
#   3799,
#   4899,
#   5266,
#   2461,
#   3008,
#   6056,
#   1362,
#   2663,
#   3422,
#   3296,
#   884],
#  [3161, 2232, 5818, 1869, 3027, 2486, 4585, 6260, 5369, 3008],
#  [6952, 5818, 7356, 6442, 3608, 5981, 1718, 6676, 2486, 3008],
#  [5818,
#   6056,
#   7268,
#   3008,
#   4153,
#   3313,
#   4941,
#   5818,
#   5162,
#   7385,
#   4264,
#   3008,
#   445,
#   2282,
#   905],
#  [6647,
#   6056,
#   325,
#   5416,
#   5981,
#   3143,
#   4689,
#   814,
#   3008,
#   4502,
#   2282,
#   1997,
#   2282,
#   277,
#   1283,
#   3842,
#   2026,
#   2765],
#  [5243, 3035, 3908, 5963, 5981, 2789],
#  [2,
#   3008,
#   5072,
#   6478,
#   297,
#   3422,
#   884,
#   5818,
#   6056,
#   6602,
#   4705,
#   6707,
#   4264,
#   4442,
#   6056,
#   6707,
#   3035],
#  [6233, 5557, 6950, 6233, 5557, 6950],
#  [1577,
#   3008,
#   5557,
#   1221,
#   5981,
#   5477,
#   3008,
#   4711,
#   5477,
#   2282,
#   4298,
#   6442,
#   1294],
#  [3422,
#   1096,
#   545,
#   1445,
#   6449,
#   905,
#   2776,
#   3201,
#   5416,
#   5082,
#   138,
#   987,
#   3422,
#   4179],
#  [3008,
#   4043,
#   6422,
#   905,
#   3008,
#   6507,
#   6478,
#   5557,
#   6412,
#   3565,
#   1221,
#   2004,
#   5557,
#   74,
#   5818,
#   797,
#   3008,
#   2236,
#   5023,
#   3904,
#   2663,
#   932,
#   1267],
#  [1169,
#   1806,
#   6442,
#   4877,
#   5072,
#   3035,
#   2326,
#   3161,
#   3008,
#   6507,
#   4589,
#   3008,
#   5072,
#   6478,
#   1869,
#   6442,
#   3964],
#  [1742, 1718, 932, 1951],
#  [5787, 4717, 2282, 1960, 1929, 74, 2218],
#  [2915, 2593, 1997, 2915, 2593, 1997],
#  [2431, 5818, 7356, 5591],
#  [1742, 1718, 4147, 1106],
#  [138,
#   5818,
#   2366,
#   2282,
#   5162,
#   4933,
#   3909,
#   88,
#   6442,
#   2789,
#   6588,
#   6647,
#   5162,
#   2218,
#   2282,
#   6795,
#   2025,
#   5072,
#   7385,
#   1960,
#   3422,
#   727,
#   4153,
#   6442,
#   7385],
#  [987,
#   1524,
#   7385,
#   7036,
#   831,
#   3909,
#   88,
#   1524,
#   1294,
#   5818,
#   5072,
#   6478,
#   7268,
#   6442,
#   3779,
#   1815,
#   6762,
#   3008,
#   7175,
#   5162,
#   1841],
#  [1742, 1718, 904, 7036],
#  [5981, 1718, 628, 3101, 3008, 1960, 6442, 727, 4153, 6442, 7385],
#  [5818,
#   2366,
#   2282,
#   325,
#   2282,
#   6442,
#   1681,
#   712,
#   2372,
#   6442,
#   7036,
#   3818,
#   3008,
#   6172,
#   905,
#   6932],
#  [1352,
#   2282,
#   905,
#   5818,
#   5072,
#   6478,
#   297,
#   2892,
#   3565,
#   6172,
#   905,
#   6442,
#   6932,
#   4264,
#   2899,
#   3008,
#   1997],
#  [6172, 905, 6442, 6932],
#  [3296, 3101, 5818, 3234, 932, 4870, 5254],
#  [5243, 1718, 932, 3698, 6678, 88, 932, 581, 2282, 6442, 4878, 2922],
#  [2625, 2403, 2338],
#  [5477, 894, 727, 6507, 3008, 7124, 2004, 3008],
#  [5818, 1869, 7385, 2765],
#  [1718, 1445, 2004, 3008, 6507, 3008, 4487, 780],
#  [4619],
#  [5254, 4486, 5343, 4899, 4153, 2939],
#  [1718, 4525, 5557, 5575],
#  [6647, 6507, 1434, 5325, 6177],
#  [5477, 772, 6507, 3008, 3590, 2282, 2572],
#  [2625, 2403],
#  [5818, 3366, 2366, 2282, 6493, 1685, 7149, 5078],
#  [712, 1718, 1445],
#  [7141, 4577, 3008, 297],
#  [5072, 3008, 14, 5477, 894, 4822, 6858, 1685, 4816, 6030],
#  [2663, 6375, 6991, 1445, 431, 5557, 6315],
#  [6315, 6442, 4822, 6858, 3313, 6315, 2765, 1685, 5557, 1134, 399],
#  [2659,
#   7385,
#   1780,
#   81,
#   4133,
#   588,
#   2766,
#   4822,
#   3290,
#   5557,
#   6315,
#   1685,
#   1929,
#   399,
#   4264,
#   5477,
#   894,
#   3008,
#   4472,
#   1734,
#   2564,
#   1685,
#   1794,
#   31,
#   5416,
#   6442,
#   6363,
#   5853,
#   4153,
#   2282,
#   2593,
#   3035,
#   5149,
#   2282,
#   1362,
#   5557,
#   4822,
#   2461,
#   5557,
#   5959,
#   2663,
#   7141,
#   5960,
#   3161,
#   3008,
#   297,
#   7073,
#   2461,
#   6478],
#  [3565,
#   5072,
#   5243,
#   5818,
#   5072,
#   134,
#   6442,
#   7343,
#   103,
#   5818,
#   134,
#   5072,
#   6478,
#   3652,
#   932,
#   7132],
#  [5072, 6478, 5534, 373],
#  [1821, 3008, 4630, 5243, 5818, 2618],
#  [3161, 255, 1380, 3565, 2366, 2663, 6442, 6035],
#  [5072, 6478, 6493, 3299],
#  [2025, 2025, 5072, 5818, 6219, 1869, 2282, 6493, 2282, 3008, 2663, 4147],
#  [3161, 6212, 7385, 2091, 7385, 2408, 7385, 7385, 6010, 1778],
#  ...]

# %%
#sorting questons and answers by the length of questions
sorted_clean_questions = []
sorted_clean_answers = []

for length in range(1, threshold + 1):
    for i in enumerate(questions_to_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_to_int[i[0]])
            sorted_clean_answers.append(answers_to_int[i[0]])

# %%
sorted_clean_questions
# Out:
# [[3789],
#  [2025],
#  [4525],
#  [2431],
#  [1205],
#  [6952],
#  [5923],
#  [6952],
#  [712],
#  [4121],
#  [6889],
#  [5243],
#  [2025],
#  [1205],
#  [2025],
#  [2236],
#  [7385],
#  [2235],
#  [1442],
#  [267],
#  [5243],
#  [2659],
#  [712],
#  [5078],
#  [2025],
#  [712],
#  [7385],
#  [5649],
#  [2248],
#  [712],
#  [2365],
#  [7385],
#  [7385],
#  [4619],
#  [5477],
#  [7385],
#  [7385],
#  [5243],
#  [6952],
#  [5243],
#  [7385],
#  [2431],
#  [6389],
#  [5243],
#  [5243],
#  [7385],
#  [1096],
#  [6952],
#  [6952],
#  [751],
#  [7385],
#  [2351],
#  [6952],
#  [2326],
#  [5383],
#  [267],
#  [6952],
#  [3012],
#  [7385],
#  [267],
#  [2055],
#  [2055],
#  [2055],
#  [2055],
#  [267],
#  [3089],
#  [6986],
#  [5078],
#  [537],
#  [4619],
#  [5243],
#  [5959],
#  [2085],
#  [3936],
#  [7385],
#  [1086],
#  [267],
#  [1548],
#  [5243],
#  [5243],
#  [267],
#  [6715],
#  [6715],
#  [6715],
#  [6715],
#  [6715],
#  [6715],
#  [5078],
#  [4619],
#  [3620],
#  [4619],
#  [2326],
#  [5477],
#  [6388],
#  [6715],
#  [6715],
#  [6715],
#  [7385],
#  [6715],
#  [6715],
#  [3620],
#  [3965],
#  [4237],
#  [4327],
#  [267],
#  [6980],
#  [267],
#  [7326],
#  [267],
#  [5954],
#  [267],
#  [6367],
#  [4525],
#  [5243],
#  [2025],
#  [1425],
#  [3745],
#  [267],
#  [2247],
#  [267],
#  [267],
#  [3092],
#  [2659],
#  [120],
#  [5383],
#  [7385],
#  [712],
#  [267],
#  [3092],
#  [4039],
#  [3092],
#  [267],
#  [3092],
#  [4251],
#  [2431],
#  [4485],
#  [7385],
#  [5102],
#  [7385],
#  [1644],
#  [7385],
#  [7385],
#  [6936],
#  [2514],
#  [6936],
#  [3745],
#  [7080],
#  [7385],
#  [6236],
#  [3092],
#  [2097],
#  [5243],
#  [2448],
#  [5954],
#  [7385],
#  [7038],
#  [1028],
#  [1615],
#  [3109],
#  [5243],
#  [267],
#  [2025],
#  [3268],
#  [3092],
#  [6498],
#  [3498],
#  [1880],
#  [6952],
#  [5078],
#  [3092],
#  [5078],
#  [3092],
#  [4619],
#  [6952],
#  [6952],
#  [4619],
#  [6952],
#  [5243],
#  [3092],
#  [6952],
#  [5243],
#  [6952],
#  [7224],
#  [7385],
#  [5243],
#  [2513],
#  [863],
#  [7385],
#  [3462],
#  [3462],
#  [5243],
#  [712],
#  [267],
#  [1598],
#  [331],
#  [4619],
#  [7385],
#  [6972],
#  [7224],
#  [7385],
#  [7385],
#  [267],
#  [6367],
#  [5285],
#  [400],
#  [1931],
#  [6972],
#  [5243],
#  [4325],
#  [2025],
#  [1189],
#  [712],
#  [712],
#  [6952],
#  [4619],
#  [2326],
#  [267],
#  [4468],
#  [267],
#  [2326],
#  [3620],
#  [6814],
#  [267],
#  [267],
#  [5243],
#  [267],
#  [7385],
#  [267],
#  [6952],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [863],
#  [2098],
#  [6952],
#  [3088],
#  [5078],
#  [6972],
#  [6972],
#  [7224],
#  [2248],
#  [7385],
#  [267],
#  [267],
#  [727],
#  [5420],
#  [5477],
#  [3818],
#  [5243],
#  [7385],
#  [2247],
#  [7385],
#  [3088],
#  [1485],
#  [267],
#  [267],
#  [2800],
#  [7056],
#  [7385],
#  [3957],
#  [712],
#  [498],
#  [6972],
#  [712],
#  [727],
#  [267],
#  [3462],
#  [2068],
#  [3462],
#  [4829],
#  [2025],
#  [7188],
#  [769],
#  [5477],
#  [4619],
#  [6952],
#  [3143],
#  [306],
#  [1679],
#  [5243],
#  [3313],
#  [1205],
#  [7385],
#  [4485],
#  [5243],
#  [7385],
#  [7385],
#  [5212],
#  [4997],
#  [4743],
#  [4997],
#  [81],
#  [4997],
#  [4997],
#  [81],
#  [6754],
#  [138],
#  [2980],
#  [2248],
#  [4327],
#  [3247],
#  [3247],
#  [7385],
#  [2235],
#  [267],
#  [5243],
#  [4619],
#  [7385],
#  [6952],
#  [4997],
#  [81],
#  [262],
#  [81],
#  [4619],
#  [7385],
#  [2431],
#  [4619],
#  [4327],
#  [4327],
#  [4619],
#  [4619],
#  [6375],
#  [4619],
#  [3088],
#  [3088],
#  [2025],
#  [4485],
#  [7385],
#  [267],
#  [5243],
#  [4166],
#  [5262],
#  [5243],
#  [3047],
#  [4720],
#  [7224],
#  [5212],
#  [5559],
#  [4302],
#  [846],
#  [3745],
#  [6272],
#  [5613],
#  [7385],
#  [874],
#  [7385],
#  [4619],
#  [6952],
#  [1742],
#  [2326],
#  [2025],
#  [5243],
#  [5243],
#  [5243],
#  [1204],
#  [5212],
#  [1904],
#  [1742],
#  [138],
#  [4619],
#  [2025],
#  [1742],
#  [6952],
#  [7385],
#  [5243],
#  [4368],
#  [4619],
#  [4619],
#  [6952],
#  [4619],
#  [7385],
#  [7385],
#  [7385],
#  [5243],
#  [3702],
#  [3620],
#  [7385],
#  [6986],
#  [5266],
#  [5243],
#  [7385],
#  [2659],
#  [7385],
#  [6216],
#  [7385],
#  [7385],
#  [3620],
#  [4619],
#  [6020],
#  [3620],
#  [4619],
#  [5913],
#  [4775],
#  [7385],
#  [4619],
#  [4619],
#  [3228],
#  [1096],
#  [1742],
#  [4619],
#  [5243],
#  [7385],
#  [7385],
#  [6367],
#  [424],
#  [3144],
#  [7385],
#  [5243],
#  [4619],
#  [6952],
#  [5053],
#  [3620],
#  [6820],
#  [4619],
#  [5243],
#  [712],
#  [5243],
#  [5420],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [2514],
#  [2974],
#  [2974],
#  [2974],
#  [7224],
#  [1742],
#  [6367],
#  [5243],
#  [4619],
#  [4619],
#  [2514],
#  [4619],
#  [1742],
#  [3349],
#  [7385],
#  [4619],
#  [4619],
#  [2707],
#  [5243],
#  [4619],
#  [169],
#  [5243],
#  [5401],
#  [3468],
#  [1585],
#  [4384],
#  [1772],
#  [4619],
#  [1931],
#  [5078],
#  [1205],
#  [5243],
#  [6952],
#  [6952],
#  [6952],
#  [6952],
#  [6952],
#  [6952],
#  [6952],
#  [1772],
#  [3294],
#  [4619],
#  [4619],
#  [2247],
#  [2707],
#  [5078],
#  [3092],
#  [6389],
#  [267],
#  [7385],
#  [6554],
#  [2247],
#  [267],
#  [2707],
#  [5243],
#  [5243],
#  [5021],
#  [5021],
#  [4619],
#  [3092],
#  [4619],
#  [6952],
#  [2326],
#  [1615],
#  [1859],
#  [267],
#  [267],
#  [6171],
#  [2326],
#  [3745],
#  [905],
#  [2125],
#  [6367],
#  [6952],
#  [5243],
#  [138],
#  [4619],
#  [6367],
#  [1838],
#  [2326],
#  [4619],
#  [4619],
#  [2586],
#  [4619],
#  [4275],
#  [6952],
#  [2025],
#  [4619],
#  [6952],
#  [4619],
#  [6367],
#  [6972],
#  [4619],
#  [5477],
#  [5228],
#  [2797],
#  [4373],
#  [3722],
#  [2659],
#  [5243],
#  [5243],
#  [5477],
#  [1615],
#  [6026],
#  [639],
#  [1343],
#  [6367],
#  [7385],
#  [1404],
#  [5243],
#  [7224],
#  [2848],
#  [7385],
#  [267],
#  [7385],
#  [7385],
#  [5243],
#  [6026],
#  [7385],
#  [6814],
#  [5243],
#  [7385],
#  [4468],
#  [4619],
#  [3745],
#  [3620],
#  [3620],
#  [3620],
#  [3706],
#  [2870],
#  [5212],
#  [5981],
#  [2575],
#  [4619],
#  [4834],
#  [4656],
#  [4619],
#  [2025],
#  [6364],
#  [4619],
#  [3620],
#  [7385],
#  [2440],
#  [7385],
#  [6364],
#  [5243],
#  [7385],
#  [6214],
#  [5383],
#  [7385],
#  [4619],
#  [6364],
#  [712],
#  [6364],
#  [6229],
#  [678],
#  [1615],
#  [2025],
#  [7385],
#  [6367],
#  [5243],
#  [6367],
#  [267],
#  [712],
#  [6952],
#  [2161],
#  [7385],
#  [3481],
#  [7385],
#  [3917],
#  [2326],
#  [5243],
#  [6952],
#  [3088],
#  [336],
#  [5243],
#  [4264],
#  [1330],
#  [4619],
#  [4560],
#  [4560],
#  [1205],
#  [5243],
#  [3088],
#  [2025],
#  [2048],
#  [5243],
#  [1934],
#  [4121],
#  [5243],
#  [1934],
#  [6952],
#  [1934],
#  [1934],
#  [5243],
#  [5078],
#  [5243],
#  [5243],
#  [3092],
#  [6100],
#  [6091],
#  [5243],
#  [3177],
#  [4176],
#  [6100],
#  [1934],
#  [6814],
#  [4502],
#  [5243],
#  [2326],
#  [2025],
#  [5243],
#  [4619],
#  [542],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [7385],
#  [5243],
#  [2235],
#  [5243],
#  [2025],
#  [2025],
#  [712],
#  [874],
#  [4619],
#  [7385],
#  [7385],
#  [7385],
#  [4619],
#  [6389],
#  [2431],
#  [4121],
#  [2025],
#  [3620],
#  [5464],
#  [1888],
#  [1163],
#  [4415],
#  [7313],
#  [833],
#  [1644],
#  [4431],
#  [976],
#  [2689],
#  [142],
#  [1644],
#  [4914],
#  [1644],
#  [3050],
#  [1644],
#  [3008],
#  [3917],
#  [712],
#  [3008],
#  [2855],
#  [5420],
#  [1205],
#  [1388],
#  [7385],
#  [3048],
#  [4619],
#  [1205],
#  [7385],
#  [7385],
#  [6668],
#  [7237],
#  [2025],
#  [1742],
#  [5243],
#  [4264],
#  [6071],
#  [3092],
#  [7385],
#  [6071],
#  [3706],
#  [4619],
#  [267],
#  [2025],
#  [4619],
#  [3620],
#  [7385],
#  [2108],
#  [7243],
#  [7385],
#  [6784],
#  [712],
#  [211],
#  [267],
#  [3745],
#  [2659],
#  [7141],
#  [537],
#  [5886],
#  [1979],
#  [6972],
#  [7385],
#  [2659],
#  [2431],
#  [5078],
#  [7385],
#  [2431],
#  [2431],
#  [4619],
#  [5243],
#  [7385],
#  [1421],
#  [5492],
#  [5127],
#  [5243],
#  [267],
#  [6952],
#  [267],
#  [5886],
#  [5243],
#  [7385],
#  [863],
#  [5078],
#  [5772],
#  [299],
#  [336],
#  [4696],
#  [267],
#  [712],
#  [267],
#  [5628],
#  [712],
#  [4619],
#  [905],
#  [1439],
#  [3439],
#  [267],
#  [267],
#  [5254],
#  [7385],
#  [3442],
#  [7385],
#  [2025],
#  [4006],
#  [5604],
#  [2514],
#  [7385],
#  [3092],
#  [3092],
#  [3745],
#  [5101],
#  [6952],
#  [267],
#  [6952],
#  [7385],
#  [373],
#  [4160],
#  [5243],
#  [4264],
#  [7385],
#  [5129],
#  [6952],
#  [2236],
#  [2595],
#  [4619],
#  [3228],
#  [4619],
#  [712],
#  [7059],
#  [7385],
#  [1742],
#  [2025],
#  [6389],
#  [6774],
#  [5954],
#  [2025],
#  [4442],
#  [6367],
#  [2025],
#  [2248],
#  [7385],
#  [267],
#  [4619],
#  [2025],
#  [2170],
#  [5243],
#  [2620],
#  [5243],
#  [267],
#  [6952],
#  [3143],
#  [5243],
#  [3620],
#  [7091],
#  [5628],
#  [5477],
#  [6233],
#  [5954],
#  [267],
#  [7224],
#  [4619],
#  [4619],
#  [2025],
#  [1151],
#  [336],
#  [6056],
#  [6952],
#  [267],
#  [328],
#  [3620],
#  [1679],
#  [3620],
#  [4674],
#  [5078],
#  [3620],
#  [5078],
#  [3620],
#  [863],
#  [1416],
#  [863],
#  [5243],
#  [2326],
#  [7385],
#  [3620],
#  [3092],
#  [4619],
#  [4468],
#  [4619],
#  [2068],
#  [4619],
#  [5243],
#  [7385],
#  [6389],
#  [3092],
#  [3706],
#  [4264],
#  [6389],
#  [6389],
#  [6952],
#  [7224],
#  [5383],
#  [5818],
#  [7385],
#  [441],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [4619],
#  [7385],
#  [7385],
#  [7385],
#  [5243],
#  [5243],
#  [5243],
#  [3582],
#  [6952],
#  [3774],
#  [2025],
#  [5243],
#  [3008],
#  [6952],
#  [6952],
#  [5243],
#  [5243],
#  [900],
#  [1424],
#  [2025],
#  [3745],
#  [7385],
#  [7385],
#  [4619],
#  [2659],
#  [2431],
#  [2659],
#  [267],
#  [2235],
#  [6260],
#  [5243],
#  [7385],
#  [2724],
#  [1615],
#  [6972],
#  [3578],
#  [6524],
#  [7385],
#  [7385],
#  [2841],
#  [2659],
#  [2659],
#  [267],
#  [5243],
#  [4078],
#  [2025],
#  [5962],
#  [6100],
#  [3309],
#  [1314],
#  [267],
#  [1314],
#  [7385],
#  [7385],
#  [7385],
#  [1314],
#  [1314],
#  [6952],
#  [6952],
#  [7385],
#  [4619],
#  [7385],
#  [6198],
#  [267],
#  [2025],
#  [3706],
#  [1742],
#  [833],
#  [2025],
#  [6952],
#  [5383],
#  [267],
#  [267],
#  [267],
#  [4619],
#  [3296],
#  [7326],
#  [7385],
#  [7385],
#  [1615],
#  [727],
#  [3442],
#  [267],
#  [4373],
#  [4619],
#  [712],
#  [267],
#  [7385],
#  [1615],
#  [905],
#  [7224],
#  [267],
#  [7188],
#  [267],
#  [5243],
#  [2366],
#  [3917],
#  [3578],
#  [5243],
#  [2582],
#  [3745],
#  [7313],
#  [4619],
#  [6952],
#  [6367],
#  [7385],
#  [5243],
#  [7385],
#  [639],
#  [4777],
#  [2431],
#  [4619],
#  [3407],
#  [5243],
#  [7385],
#  [6389],
#  [6974],
#  [4373],
#  [4619],
#  [4619],
#  [865],
#  [6952],
#  [7385],
#  [5243],
#  [5078],
#  [5078],
#  [4619],
#  [2025],
#  [2235],
#  [4619],
#  ...]
